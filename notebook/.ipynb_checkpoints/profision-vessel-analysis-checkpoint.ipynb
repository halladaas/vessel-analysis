# %% [markdown]
# # 1. Data Loading and Cleaning

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from shapely.geometry import Point, Polygon

# %% [markdown]
# ## Loading Data

# %%
positions = pd.read_csv('../data/vessel_positions.csv')
characteristics = pd.read_csv('../data/vessel_characteristics.csv')
# Out:
# /var/folders/_h/908hqbz56jj3y35px7511bzr0000gn/T/ipykernel_85759/1822538655.py:1: DtypeWarning: Columns (20,21,25,26,29,30) have mixed types. Specify dtype option on import or set low_memory=False.
#   positions = pd.read_csv('../data/vessel_positions.csv')
# /var/folders/_h/908hqbz56jj3y35px7511bzr0000gn/T/ipykernel_85759/1822538655.py:2: DtypeWarning: Columns (42,47,72,81,154,163,210) have mixed types. Specify dtype option on import or set low_memory=False.
#   characteristics = pd.read_csv('../data/vessel_characteristics.csv')

# %%
# View shape and preview

print("Positions:", positions.shape)
print("Characteristics:", characteristics.shape)
# Out:
# Positions: (71635, 54)
# Characteristics: (14757, 212)

# %%
positions.head()
# Out:
#    index      imo  vessel_dwt status_date_time  in_blackout  ais_speed  \
# 0      0  1014149       11717       20/08/2024            0        0.0
# 1      1  1014163       39815       20/08/2024            0        0.0
# 2      2  1014199       11722       20/08/2024            0        0.0
# 3      3  1014254       13465       20/08/2024            0       11.8
# 4      4  1014591       39415       20/08/2024            0       11.0
#
#    ais_draft  vessel_speed_ratio  ais_lat  ais_long  ...  \
# 0        5.1                 NaN  34.3504   133.877  ...
# 1        6.1                 NaN -33.8022   137.052  ...
# 2        4.4                 NaN  34.4042   133.425  ...
# 3        9.5                 NaN  11.7398   109.489  ...
# 4       10.6                 NaN  16.4267   113.858  ...
#
#   real_destination_country_name  real_destination_zone_id  \
# 0                         Japan                      73.0
# 1                         China                      73.0
# 2                         Japan                      73.0
# 3                         Japan                      73.0
# 4                           NaN                       NaN
#
#   real_destination_zone_name vessel_operational_status  \
# 0                   Far East              waiting_load
# 1                   Far East              at_port_load
# 2                   Far East              waiting_load
# 3                   Far East              at_sea_laden
# 4                        NaN              at_sea_laden
#
#   vessel_commodity_onboard vessel_commodity_group_onboard  voyage_intake_mt  \
# 0                      NaN                            NaN               NaN
# 1                    Grain                          Grain           27320.0
# 2                      NaN                            NaN               NaN
# 3                   Steels                         Steels           12353.0
# 4                   Steels                         Steels           36350.0
#
#           last_seen  during_cabotage_voyage vessel_operational_status_group
# 0  19/08/2024 23:56                       1      at_port_waiting_load_group
# 1  19/08/2024 23:56                       0           in_port_loading_group
# 2  19/08/2024 23:59                       1      at_port_waiting_load_group
# 3  19/08/2024 23:59                       1              at_sea_laden_group
# 4  19/08/2024 23:52                       0              at_sea_laden_group
#
# [5 rows x 54 columns]

# %%
characteristics.head()
# Out:
#        id      imo axs_notes_dry                name          type  \
# 0   83576  9122590           NaN          BERGE FUJI  Bulk carrier
# 1   94194  9237230           NaN          XH VOYAGER  Bulk carrier
# 2   97323  9270567           NaN         CAPE TOUCAN  Bulk carrier
# 3   98092  9279393           NaN  WINNING EXCELLENCE  Bulk carrier
# 4  102164  9321275           NaN         BRASIL MARU  Bulk carrier
#
#        subtype ship_status                     registered_owner  \
# 0  Ore Carrier   DELIVERED                BERGE MAUNA KEA CO SA
# 1  Ore Carrier   DELIVERED                  FOND MARINE PTE LTD
# 2  Ore Carrier   DELIVERED                 POLGRYN SHIPPING INC
# 3  Ore Carrier   DELIVERED  WINNING EXCELLENCE SHIPPING PTE LTD
# 4  Ore Carrier   DELIVERED                                  MOL
#
#                  ship_owner               tc_operator  ... cranes_number  \
# 0                BERGE BULK                BERGE BULK  ...             0
# 1  ZHOUSHAN XIEHAI SHIPPING  ZHOUSHAN XIEHAI SHIPPING  ...             0
# 2           ZODIAC MARITIME           ZODIAC MARITIME  ...             0
# 3       WINNING SHIPPING HK       WINNING SHIPPING HK  ...             0
# 4                       MOL                       MOL  ...             0
#
#   cranes_swl cranes_outreach cranes_position  \
# 0        0.0               0             NaN
# 1        0.0               0             NaN
# 2        0.0               0             NaN
# 3        0.0               0             NaN
# 4        0.0               0             NaN
#
#                                         hold_details  \
# 0                                                NaN
# 1  No. 1 : - cbm;No. 2 : - cbm;No. 3 : - cbm;No. ...
# 2  No. 1 : - cbm;No. 2 : - cbm;No. 3 : - cbm;No. ...
# 3                                                NaN
# 4                                                NaN
#
#                                      hatches_details  private_comments  \
# 0                                                NaN                 0
# 1  No. 1 : - m X - m;No. 2 : - m X - m;No. 3 : - ...                 0
# 2  No. 1 : 16.91 m X 16 m;No. 2 : 16.91 m X 16 m;...                 0
# 3                                                NaN                 0
# 4                                                NaN                 0
#
#    private_tags  conversion_date  private_notes
# 0           NaN              NaN            NaN
# 1           NaN              NaN            NaN
# 2           NaN              NaN            NaN
# 3           NaN              NaN            NaN
# 4           NaN              NaN            NaN
#
# [5 rows x 212 columns]

# %%
positions.columns
# Out:
# Index(['index', 'imo', 'vessel_dwt', 'status_date_time', 'in_blackout',
#        'ais_speed', 'ais_draft', 'vessel_speed_ratio', 'ais_lat', 'ais_long',
#        'vessel_draft_status', 'zone_id', 'zone_name', 'zone_entry_time',
#        'zone_out_time', 'updated_at', 'country_id', 'country_name', 'port_id',
#        'port_name', 'port_entry_time', 'port_out_time',
#        'operation_location_id', 'operation_location_name',
#        'operation_location_type', 'operation_location_entry_time',
#        'operation_location_out_time', 'waiting_zone_id', 'waiting_zone_name',
#        'waiting_zone_entry_time', 'waiting_zone_out_time', 'ais_heading',
#        'ais_eta', 'ais_destination_raw', 'ais_destination_normalized',
#        'origin_port_id', 'origin_port_name', 'origin_country_id',
#        'origin_country_name', 'origin_zone_id', 'origin_zone_name',
#        'real_destination_port_id', 'real_destination_port_name',
#        'real_destination_country_id', 'real_destination_country_name',
#        'real_destination_zone_id', 'real_destination_zone_name',
#        'vessel_operational_status', 'vessel_commodity_onboard',
#        'vessel_commodity_group_onboard', 'voyage_intake_mt', 'last_seen',
#        'during_cabotage_voyage', 'vessel_operational_status_group'],
#       dtype='object')

# %% [markdown]
# ## Feature Inspection and Observation of Erroneous Data Points

# %% [markdown]
# ### Positions

# %%
for c in positions.columns:
    print(positions[c].value_counts())
# Out:
# index
# 0        1
# 47755    1
# 47761    1
# 47760    1
# 47759    1
#         ..
# 23883    1
# 23884    1
# 23885    1
# 23886    1
# 71634    1
# Name: count, Length: 71635, dtype: int64
# imo
# 1014149    5
# 9287194    5
# 9286906    5
# 9286918    5
# 9286920    5
#           ..
# 8811390    4
# 9953705    3
# 9966831    1
# 9885300    1
# 9986910    1
# Name: count, Length: 14330, dtype: int64
# vessel_dwt
# 58018     185
# 63301      90
# 57809      85
# 76596      85
# 324690     65
#          ...
# 15          1
# 13417       1
# 93          1
# 142         1
# 82781       1
# Name: count, Length: 10524, dtype: int64
# status_date_time
# 24/08/2024    14329
# 22/08/2024    14327
# 23/08/2024    14327
# 20/08/2024    14326
# 21/08/2024    14326
# Name: count, dtype: int64
# in_blackout
# 0    68990
# 1     2645
# Name: count, dtype: int64
# ais_speed
# 0.0     23158
# 0.1      5351
# 11.0     3336
# 12.0     2522
# 10.0     2518
#         ...
# 20.8        1
# 49.4        1
# 39.5        1
# 37.3        1
# 55.7        1
# Name: count, Length: 289, dtype: int64
# ais_draft
# 6.5     1591
# 7.0     1471
# 7.2     1433
# 7.1     1411
# 6.4     1178
#         ...
# 2.7        1
# 2.2        1
# 1.4        1
# 3.1        1
# 19.2       1
# Name: count, Length: 213, dtype: int64
# vessel_speed_ratio
# 0.00     20117
# 0.69      1741
# 75.86     1010
# 0.71       856
# 68.97      799
#          ...
# 46.58        1
# 8.90         1
# 96.08        1
# 39.72        1
# 41.33        1
# Name: count, Length: 3077, dtype: int64
# ais_lat
#  0.0000     61
#  33.8183    34
#  34.7483    14
#  30.0842    14
#  35.9978    12
#             ..
# -1.1249      1
# -6.6033      1
# -35.6643     1
#  7.4018      1
#  6.8133      1
# Name: count, Length: 55915, dtype: int64
# ais_long
# 0.0000      60
# 118.4550    49
# 35.4908     38
# 119.5340    28
# 122.2730    21
#             ..
# 55.5633      1
# 116.8100     1
# 101.6980     1
# 55.0715      1
# 98.3317      1
# Name: count, Length: 49234, dtype: int64
# vessel_draft_status
# laden      42710
# ballast    28871
# Name: count, dtype: int64
# zone_id
# 73.0       17204
# 72.0       12361
# 46.0        3776
# 69.0        2766
# 68.0        2456
# 319.0       2354
# 59.0        2180
# 71.0        1888
# 66.0        1817
# 64.0        1742
# 60.0        1709
# 58.0        1562
# 67.0        1456
# 55.0        1454
# 40.0        1424
# 61.0        1163
# 74.0        1069
# 65.0        1006
# 56.0         959
# 70.0         902
# 52.0         882
# 53.0         857
# 54.0         847
# 41.0         795
# 23676.0      752
# 23663.0      610
# 51.0         547
# 48.0         531
# 63.0         455
# 42.0         441
# 47.0         426
# 43.0         406
# 45.0         393
# 23668.0      357
# 57.0         332
# 49.0         332
# 23669.0      226
# 44.0         221
# 50.0         215
# 62.0         178
# 23679.0       49
# 23680.0       38
# 23670.0       34
# Name: count, dtype: int64
# zone_name
# Far East                             17204
# South East Asia                      12361
# East Coast South America              3776
# Indian Ocean                          2766
# Arabian Gulf                          2456
# South Atlantic                        2354
# East Mediterranean                    2180
# East Coast India                      1888
# South Africa                          1817
# North West Africa                     1742
# Black Sea                             1709
# West Mediterranean                    1562
# East Africa                           1456
# East Aussie                           1454
# NoPac                                 1424
# Antwerp Rotterdam Amsterdam Ghent     1163
# Red Sea                               1069
# South West Africa                     1006
# West Aussie                            959
# West Coast India                       902
# USG                                    882
# West Coast Central America             857
# West Coast South America               847
# Baltic                                 795
# Mid-North Atlantic                     752
# Central Atlantic                       610
# East Coast U.S                         547
# North Coast South America              531
# Spain Atlantic                         455
# Carribbean                             441
# Great Lakes                            426
# North Continent                        406
# East Coast Central America             393
# South Indian Ocean                     357
# New Zealand                            332
# Saint Lawrence                         332
# Mid Pacific                            226
# East Coast Canada                      221
# United Kingdom Ireland                 215
# French Atlantic                        178
# North East Passage                      49
# North West Passage                      38
# South Pacific                           34
# Name: count, dtype: int64
# zone_entry_time
# 01/01/2013 00:04    45
# 01/01/2013 00:05    45
# 01/01/2013 00:03    40
# 05/08/2024 06:43    27
# 13/08/2024 18:45    25
#                     ..
# 01/08/2024 03:47     1
# 02/08/2024 16:58     1
# 02/08/2024 15:39     1
# 12/08/2024 16:01     1
# 23/08/2024 11:41     1
# Name: count, Length: 14944, dtype: int64
# zone_out_time
# 07/10/2024 02:59    247
# 07/10/2024 03:09    229
# 07/10/2024 03:08    186
# 07/10/2024 02:58    184
# 07/10/2024 03:19    183
#                    ...
# 20/08/2024 21:10      1
# 23/08/2024 02:50      1
# 20/08/2024 13:01      1
# 23/08/2024 01:19      1
# 29/08/2024 21:00      1
# Name: count, Length: 12693, dtype: int64
# updated_at
# 07/10/2024    8751
# 24/09/2024    6989
# 26/09/2024    5510
# 10/10/2024    1944
# 27/08/2024    1816
# 30/08/2024    1803
# 29/08/2024    1771
# 03/09/2024    1748
# 31/08/2024    1687
# 05/09/2024    1663
# 28/08/2024    1663
# 01/09/2024    1604
# 06/09/2024    1485
# 02/09/2024    1446
# 04/09/2024    1402
# 24/08/2024    1383
# 08/09/2024    1331
# 07/09/2024    1328
# 10/09/2024    1314
# 12/09/2024    1259
# 09/09/2024    1254
# 23/08/2024    1120
# 11/09/2024    1116
# 13/09/2024    1052
# 15/09/2024     953
# 14/09/2024     933
# 01/10/2024     916
# 27/09/2024     911
# 02/10/2024     904
# 16/09/2024     863
# 03/10/2024     844
# 20/09/2024     820
# 17/09/2024     818
# 05/10/2024     805
# 19/09/2024     792
# 06/10/2024     792
# 22/08/2024     757
# 28/09/2024     753
# 04/10/2024     736
# 22/09/2024     731
# 18/09/2024     718
# 25/09/2024     705
# 30/09/2024     680
# 21/09/2024     671
# 29/09/2024     618
# 23/09/2024     558
# 26/08/2024     510
# 25/08/2024     460
# 21/08/2024     440
# 09/10/2024     168
# 20/08/2024     147
# 08/10/2024     139
# Name: count, dtype: int64
# country_id
# 9605.0    6562
# 9715.0    1740
# 9594.0    1540
# 9584.0    1102
# 9751.0     920
#           ...
# 9617.0       1
# 9757.0       1
# 9728.0       1
# 9720.0       1
# 9753.0       1
# Name: count, Length: 138, dtype: int64
# country_name
# China                      6562
# Indonesia                  1740
# Brazil                     1540
# Australia                  1102
# USA                         920
#                            ...
# Cape Verde                    1
# Samoa                         1
# Saint Lucia                   1
# American Samoa                1
# Virgin Islands, British       1
# Name: count, Length: 138, dtype: int64
# port_id
# 351.0      765
# 350.0      602
# 2817.0     461
# 20836.0    315
# 2008.0     312
#           ...
# 4064.0       1
# 2874.0       1
# 30998.0      1
# 31053.0      1
# 8817.0       1
# Name: count, Length: 1261, dtype: int64
# port_name
# Ningbo (incl Zhoushan)    765
# Shanghai                  602
# Tianjin                   461
# Caofeidian                315
# Chittagong                312
#                          ...
# Stavanger                   1
# Oristano                    1
# Meldrum Bay                 1
# Port Dolomite               1
# Port Sultan Qaboos          1
# Name: count, Length: 1261, dtype: int64
# port_entry_time
# 45527.88119         9
# 45523.24943         8
# 45524.9442          8
# 45528.03428         7
# 45525.9855          7
#                    ..
# 01/08/2024 10:45    1
# 06/08/2024 07:36    1
# 19/08/2024 09:51    1
# 21/08/2024 11:38    1
# 45529.14736         1
# Name: count, Length: 8764, dtype: int64
# port_out_time
# 45529.47156         8
# 45529.08981         7
# 45528.68035         7
# 45539.21434         6
# 45531.09686         6
#                    ..
# 05/09/2024 12:55    1
# 06/09/2024 11:29    1
# 20/08/2024 01:45    1
# 31/08/2024 01:49    1
# 45531.14535         1
# Name: count, Length: 8760, dtype: int64
# operation_location_id
# 20812.0    363
# 23607.0    245
# 21647.0    230
# 20818.0    216
# 7946.0     203
#           ...
# 34923.0      1
# 28378.0      1
# 28783.0      1
# 3892.0       1
# 26821.0      1
# Name: count, Length: 3247, dtype: int64
# operation_location_name
# Outer Yangtze Estuary Anchorage North    363
# Chittagong Anchorage                     245
# Huanghua Anchorages                      230
# Outer Zhoushan Anchorage & STS           216
# Taboneo - Banjarmasin                    203
#                                         ...
# Suizhong Anchorage                         1
# Yarra River Southern berths - import       1
# Daebul Wharf - Unknown Silos               1
# Vladivostok                                1
# DBT Export Berth 703                       1
# Name: count, Length: 3247, dtype: int64
# operation_location_type
# anchorage    12649
# berth         8432
# port          2022
# shipyard      1393
# waypoint        26
# Name: count, dtype: int64
# operation_location_entry_time
# 19/08/2024 04:29    10
# 19/08/2024 22:29     9
# 45522.64572          8
# 19/08/2024 23:09     8
# 45519.74929          8
#                     ..
# 45524.78414          1
# 45517.0002           1
# 45520.06221          1
# 45519.79831          1
# 45527.6447           1
# Name: count, Length: 13569, dtype: int64
# operation_location_out_time
# 20/08/2024 02:59    11
# 20/08/2024 01:09    10
# 45528.92983          8
# 45529.22845          8
# 20/08/2024 03:09     8
#                     ..
# 20/08/2024 10:12     1
# 45525.45852          1
# 23/08/2024 01:30     1
# 21/08/2024 19:23     1
# 45530.45059          1
# Name: count, Length: 13563, dtype: int64
# waiting_zone_id
# 20812.0    786
# 20830.0    444
# 20818.0    361
# 21647.0    314
# 21601.0    301
#           ...
# 30469.0      1
# 39656.0      1
# 31708.0      1
# 38904.0      1
# 36768.0      1
# Name: count, Length: 1008, dtype: int64
# waiting_zone_name
# Outer Yangtze Estuary Anchorage North      786
# Outer Yangtze Estuary Anchorage South      444
# Outer Zhoushan Anchorage & STS             361
# Huanghua Anchorages                        314
# Caofeidian Anchorage                       301
#                                           ...
# Outer Delaware Transhipment Anchorage 1      1
# Tokushima Anchorage                          1
# Chekka Anchorage                             1
# New London Anchorage                         1
# Tanjung Uncang Anchorage                     1
# Name: count, Length: 1007, dtype: int64
# waiting_zone_entry_time
# 19/08/2024 22:29    9
# 45519.74929         8
# 45524.083           8
# 19/08/2024 20:59    7
# 19/08/2024 23:29    7
#                    ..
# 11/08/2024 04:58    1
# 12/08/2024 09:48    1
# 15/08/2024 02:49    1
# 15/08/2024 07:58    1
# 45527.94419         1
# Name: count, Length: 12231, dtype: int64
# waiting_zone_out_time
# 45526.70082         8
# 45528.88824         7
# 20/08/2024 01:39    7
# 45528.33939         7
# 20/08/2024 00:29    7
#                    ..
# 25/08/2024 01:29    1
# 10/08/2024 08:39    1
# 15/08/2024 00:20    1
# 07/08/2024 06:09    1
# 45528.36741         1
# Name: count, Length: 12378, dtype: int64
# ais_heading
# 0.0      1715
# 511.0     765
# 270.0     367
# 269.0     337
# 359.0     321
#          ...
# 153.0     127
# 157.0     126
# 158.0     118
# 463.0       1
# 413.0       1
# Name: count, Length: 363, dtype: int64
# ais_eta
# 24/08/2024 12:00    331
# 20/08/2024 12:00    273
# 23/08/2024 12:00    272
# 25/08/2024 12:00    262
# 26/08/2024 12:00    256
#                    ...
# 17/08/2024 09:24      1
# 28/07/2024 20:15      1
# 22/08/2024 15:10      1
# 22/08/2024 23:57      1
# 09/10/2024 15:30      1
# Name: count, Length: 4614, dtype: int64
# ais_destination_raw
# SG SIN           1247
# SINGAPORE        1061
# SGSIN             596
# BR SSZ            456
# AU PHE            424
#                  ...
# PATER NOSTER        1
# JP MKX OFF          1
# SEVAG               1
# >SG PE>TWKHH        1
# >JP MIZ B 18B       1
# Name: count, Length: 7768, dtype: int64
# ais_destination_normalized
# Singapore      4422
# Santos         1077
# Zhoushan       1036
# Qingdao         961
# World Wide      820
#                ...
# Nepoui            1
# Southampton       1
# Rahja             1
# Palua             1
# Ranong            1
# Name: count, Length: 1738, dtype: int64
# origin_port_id
# 2817.0     1345
# 3851.0     1176
# 20836.0     967
# 1729.0      909
# 4597.0      687
#            ...
# 1217.0        1
# 3180.0        1
# 23209.0       1
# 1381.0        1
# 1495.0        1
# Name: count, Length: 1465, dtype: int64
# origin_port_name
# Tianjin         1345
# Santos          1176
# Caofeidian       967
# Port Hedland     909
# Huanghua         687
#                 ...
# Weserport          1
# Charlevoix         1
# Ningbo             1
# Manokwari          1
# Lautoka            1
# Name: count, Length: 1465, dtype: int64
# origin_country_id
# 9605.0    15443
# 9594.0     5478
# 9715.0     4513
# 9584.0     4357
# 9751.0     3615
#           ...
# 9617.0        1
# 9736.0        1
# 9713.0        1
# 9633.0        1
# 9677.0        1
# Name: count, Length: 144, dtype: int64
# origin_country_name
# China                               15443
# Brazil                               5478
# Indonesia                            4513
# Australia                            4357
# USA                                  3615
#                                     ...
# Cape Verde                              1
# Saint Vincent and the Grenadines        1
# Reunion                                 1
# French Guiana                           1
# Martinique                              1
# Name: count, Length: 144, dtype: int64
# origin_zone_id
# 73.0       21108
# 72.0        8723
# 46.0        6913
# 60.0        2531
# 55.0        2435
# 71.0        2360
# 68.0        2275
# 59.0        2106
# 56.0        1922
# 41.0        1730
# 52.0        1678
# 64.0        1444
# 40.0        1440
# 70.0        1384
# 61.0        1281
# 54.0        1208
# 58.0        1034
# 51.0         983
# 66.0         947
# 65.0         890
# 48.0         797
# 49.0         605
# 67.0         552
# 74.0         550
# 43.0         477
# 53.0         445
# 47.0         419
# 63.0         376
# 57.0         311
# 45.0         264
# 50.0         229
# 44.0         221
# 42.0         196
# 62.0          67
# 69.0          34
# 23680.0       32
# 23679.0       13
# 23676.0        5
# 23669.0        2
# Name: count, dtype: int64
# origin_zone_name
# Far East                             21108
# South East Asia                       8723
# East Coast South America              6913
# Black Sea                             2531
# East Aussie                           2435
# East Coast India                      2360
# Arabian Gulf                          2275
# East Mediterranean                    2106
# West Aussie                           1922
# Baltic                                1730
# USG                                   1678
# North West Africa                     1444
# NoPac                                 1440
# West Coast India                      1384
# Antwerp Rotterdam Amsterdam Ghent     1281
# West Coast South America              1208
# West Mediterranean                    1034
# East Coast U.S                         983
# South Africa                           947
# South West Africa                      890
# North Coast South America              797
# Saint Lawrence                         605
# East Africa                            552
# Red Sea                                550
# North Continent                        477
# West Coast Central America             445
# Great Lakes                            419
# Spain Atlantic                         376
# New Zealand                            311
# East Coast Central America             264
# United Kingdom Ireland                 229
# East Coast Canada                      221
# Carribbean                             196
# French Atlantic                         67
# Indian Ocean                            34
# North West Passage                      32
# North East Passage                      13
# Mid-North Atlantic                       5
# Mid Pacific                              2
# Name: count, dtype: int64
# real_destination_port_id
# 2817.0     1317
# 3851.0     1036
# 20836.0     907
# 1729.0      906
# 2008.0      685
#            ...
# 1576.0        1
# 24690.0       1
# 953.0         1
# 7973.0        1
# 19968.0       1
# Name: count, Length: 1443, dtype: int64
# real_destination_port_name
# Tianjin                           1317
# Santos                            1036
# Caofeidian                         907
# Port Hedland                       906
# Chittagong                         685
#                                   ...
# Devonport                            1
# Tonganda Wood/Logs Export Area       1
# Gioia Tauro                          1
# Tsuneishi                            1
# Caldera (Chile)                      1
# Name: count, Length: 1443, dtype: int64
# real_destination_country_id
# 9605.0     15876
# 9594.0      5511
# 9584.0      4066
# 9715.0      3626
# 9751.0      3447
#            ...
# 9612.0         4
# 9720.0         3
# 31889.0        3
# 9596.0         3
# 9728.0         1
# Name: count, Length: 144, dtype: int64
# real_destination_country_name
# China               15876
# Brazil               5511
# Australia            4066
# Indonesia            3626
# USA                  3447
#                     ...
# Comoros                 4
# American Samoa          3
# Christmas Island        3
# Bahamas                 3
# Saint Lucia             1
# Name: count, Length: 144, dtype: int64
# real_destination_zone_id
# 73.0       21544
# 72.0        7700
# 46.0        6556
# 59.0        2512
# 71.0        2408
# 68.0        2308
# 55.0        2239
# 60.0        1991
# 56.0        1827
# 61.0        1801
# 52.0        1705
# 70.0        1620
# 64.0        1541
# 58.0        1345
# 41.0        1268
# 40.0        1221
# 54.0        1025
# 65.0        1001
# 66.0         920
# 74.0         858
# 51.0         814
# 67.0         650
# 48.0         627
# 53.0         594
# 49.0         535
# 63.0         478
# 47.0         470
# 45.0         388
# 43.0         382
# 57.0         356
# 50.0         273
# 42.0         236
# 44.0         164
# 62.0          59
# 69.0          52
# 23679.0       40
# 23680.0       26
# 23670.0       15
# 23669.0       13
# 23676.0        5
# Name: count, dtype: int64
# real_destination_zone_name
# Far East                             21544
# South East Asia                       7700
# East Coast South America              6556
# East Mediterranean                    2512
# East Coast India                      2408
# Arabian Gulf                          2308
# East Aussie                           2239
# Black Sea                             1991
# West Aussie                           1827
# Antwerp Rotterdam Amsterdam Ghent     1801
# USG                                   1705
# West Coast India                      1620
# North West Africa                     1541
# West Mediterranean                    1345
# Baltic                                1268
# NoPac                                 1221
# West Coast South America              1025
# South West Africa                     1001
# South Africa                           920
# Red Sea                                858
# East Coast U.S                         814
# East Africa                            650
# North Coast South America              627
# West Coast Central America             594
# Saint Lawrence                         535
# Spain Atlantic                         478
# Great Lakes                            470
# East Coast Central America             388
# North Continent                        382
# New Zealand                            356
# United Kingdom Ireland                 273
# Carribbean                             236
# East Coast Canada                      164
# French Atlantic                         59
# Indian Ocean                            52
# North East Passage                      40
# North West Passage                      26
# South Pacific                           15
# Mid Pacific                             13
# Mid-North Atlantic                       5
# Name: count, dtype: int64
# vessel_operational_status
# at_sea_laden               25793
# at_sea_ballast             21266
# at_port_discharging         5831
# at_port_load                5341
# waiting_load                4503
# waiting_discharge           4222
# waiting_at_anchorage        2824
# in_shipyard                 1393
# waiting_shipyard             154
# bunkering_while_laden         95
# bunkering_while_ballast       73
# at_port_load_sts              33
# at_port_discharge_sts         18
# passing_canal_laden           13
# passing_canal_ballast         13
# sts                            9
# Name: count, dtype: int64
# vessel_commodity_onboard
# Steam Coal                   6375
# Iron Ore                     2790
# Steels                       2478
# Wheat                        1786
# Soybeans                     1723
#                              ...
# Steam Coal/Steels               2
# Dried Distillers Grains         1
# Building Materials/Cement       1
# Calcium Oxide                   1
# Iron Ore/Ores                   1
# Name: count, Length: 171, dtype: int64
# vessel_commodity_group_onboard
# Coal                    8614
# Bulk                    7667
# Grain                   6108
# Iron Ore                4616
# Steels                  3614
# Breakbulk               2926
# Fertilizers             2707
# Agriprods               2276
# Project Cargoes          247
# Pellets Group            168
# Iron Products            152
# Coal/Iron Ore             19
# Bulk/Steels               14
# Iron Products/Steels       9
# Breakbulk/Steels           7
# Bulk/Iron Ore              6
# Breakbulk/Bulk             6
# Bulk/Iron Products         4
# Coal/Steels                2
# Name: count, dtype: int64
# voyage_intake_mt
# 201794.0    20
# 47981.0     20
# 31632.0     20
# 26990.0     15
# 30238.0     15
#             ..
# 23698.0      1
# 59719.0      1
# 43227.0      1
# 42954.0      1
# 103410.0     1
# Name: count, Length: 9241, dtype: int64
# last_seen
# 19/08/2024 23:59    1753
# 20/08/2024 23:58    1751
# 22/08/2024 23:58    1729
# 19/08/2024 23:58    1680
# 21/08/2024 23:58    1677
#                     ...
# 21/08/2024 01:49       1
# 21/08/2024 21:59       1
# 19/08/2024 20:22       1
# 21/08/2024 16:38       1
# 23/08/2024 19:00       1
# Name: count, Length: 2086, dtype: int64
# during_cabotage_voyage
# 0    60806
# 1    10829
# Name: count, dtype: int64
# vessel_operational_status_group
# at_sea_laden_group                 25901
# at_sea_ballast_group               21352
# in_port_discharging_group           5831
# in_port_loading_group               5341
# at_port_waiting_load_group          4503
# inactive_group                      4371
# at_port_waiting_discharge_group     4222
# sts_group                             60
# Name: count, dtype: int64

# %% [markdown]
# #### From the above inspection, we can see errenous entries in port_entry_time, operation_location_entry_time, operation_location_out_time, waiting_zone_entry_time, waiting_zone_out_time, ex formats:
# float: 45524.9442 <br>
# datetime: 01/08/2024 10:45

# %% [markdown]
# ### Characteristics

# %%
characteristics.columns.tolist()
# Out:
# ['id',
#  'imo',
#  'axs_notes_dry',
#  'name',
#  'type',
#  'subtype',
#  'ship_status',
#  'registered_owner',
#  'ship_owner',
#  'tc_operator',
#  'beneficial_owner',
#  'flag',
#  'built',
#  'demolition_date',
#  'dwt',
#  'summer_fresh_water_dwt',
#  'winter_salt_water_dwt',
#  'tropical_salt_water_dwt',
#  'tropical_fresh_water_dwt',
#  'lbp',
#  'loa',
#  'beam',
#  'draft',
#  'winter_salt_water_draft',
#  'tropical_salt_water_draft',
#  'summer_fresh_water_draft',
#  'tropical_fresh_water_draft',
#  'depth',
#  'tpc',
#  'winter_salt_water_tpc',
#  'tropical_salt_water_tpc',
#  'summer_fresh_water_tpc',
#  'tropical_fresh_water_tpc',
#  'air_draft',
#  'gt',
#  'suez_gt',
#  'panama_gt',
#  'nt',
#  'suez_nt',
#  'panama_nt',
#  'ldt',
#  'shipyard',
#  'second_shipyard',
#  'hull_number',
#  'design',
#  'total_main_engines',
#  'bow_thruster',
#  'stern_thruster',
#  'geared',
#  'grabs_number',
#  'grabs_capacity',
#  'total_decks',
#  'grain',
#  'bale',
#  'holds',
#  'hatches',
#  'active',
#  'call_sign',
#  'open_hatches',
#  'lakes_fitted',
#  'logs_fitted',
#  'ahl_fitted',
#  'co2_fitted',
#  'keel_laying_date',
#  'launching_date',
#  'reported_date',
#  'cancelled_date',
#  'mmsi',
#  'ice_class',
#  'ballast_water',
#  'shipbuilding_group',
#  'technical_manager',
#  'pool',
#  'parent_shipowner',
#  'doc_holder',
#  'crew_manager',
#  'ism_manager',
#  'dual_fuel',
#  'scrubbers',
#  'bwts',
#  'ordering_company',
#  'demolition_country',
#  'full_ballast_speed',
#  'full_laden_speed',
#  'eco_ballast_speed',
#  'eco_laden_speed',
#  'full_ballast_hsfo',
#  'full_laden_hsfo',
#  'eco_ballast_hsfo',
#  'eco_laden_hsfo',
#  'port_load_hsfo',
#  'in_port_idle_hsfo',
#  'full_ballast_ae_lsmgo',
#  'full_laden_ae_lsmgo',
#  'eco_ballast_ae_lsmgo',
#  'eco_laden_ae_lsmgo',
#  'port_load_ae_lsmgo',
#  'in_port_idle_ae_lsmgo',
#  'full_ballast_lsmgo',
#  'full_laden_lsmgo',
#  'eco_ballast_lsmgo',
#  'eco_laden_lsmgo',
#  'port_load_lsmgo',
#  'in_port_idle_lsmgo',
#  'fresh_water',
#  'constants',
#  'full_laden_vlsfo',
#  'full_ballast_vlsfo',
#  'eco_laden_vlsfo',
#  'eco_ballast_vlsfo',
#  'port_load_vlsfo',
#  'in_port_idle_vlsfo',
#  'eco_2_ballast_speed',
#  'eco_2_laden_speed',
#  'eco_2_ballast_hsfo',
#  'eco_2_laden_hsfo',
#  'eco_2_ballast_ae_lsmgo',
#  'eco_2_laden_ae_lsmgo',
#  'eco_2_ballast_lsmgo',
#  'eco_2_laden_lsmgo',
#  'eco_2_ballast_vlsfo',
#  'eco_2_laden_vlsfo',
#  'canal_hsfo',
#  'canal_ae_lsmgo',
#  'canal_lsmgo',
#  'canal_vlsfo',
#  'port_disch_hsfo',
#  'port_disch_ae_lsmgo',
#  'port_disch_lsmgo',
#  'port_disch_vlsfo',
#  'hsfo_tank',
#  'lsmgo_tank',
#  'vlsfo_tank',
#  'hatches_type',
#  'tts',
#  'category',
#  'market_segment',
#  'update_date',
#  'registered_owner_id',
#  'registered_owner_flag',
#  'registered_owner_flag_id',
#  'ship_owner_id',
#  'ship_owner_flag',
#  'ship_owner_flag_id',
#  'tc_operator_id',
#  'tc_operator_flag',
#  'tc_operator_flag_id',
#  'beneficial_owner_id',
#  'beneficial_owner_flag',
#  'beneficial_owner_flag_id',
#  'shipyard_id',
#  'shipyard_flag',
#  'shipyard_flag_id',
#  'second_shipyard_id',
#  'second_shipyard_flag',
#  'second_shipyard_flag_id',
#  'shipbuilding_group_id',
#  'shipbuilding_group_flag',
#  'shipbuilding_group_flag_id',
#  'technical_manager_id',
#  'technical_manager_flag',
#  'technical_manager_flag_id',
#  'pool_id',
#  'pool_flag',
#  'pool_flag_id',
#  'parent_shipowner_id',
#  'parent_shipowner_flag',
#  'parent_shipowner_flag_id',
#  'doc_holder_id',
#  'doc_holder_flag',
#  'doc_holder_flag_id',
#  'crew_manager_id',
#  'crew_manager_flag',
#  'crew_manager_flag_id',
#  'ism_manager_id',
#  'ism_manager_flag',
#  'ism_manager_flag_id',
#  'ordering_company_id',
#  'ordering_company_flag',
#  'ordering_company_flag_id',
#  'type_id',
#  'subtype_id',
#  'ship_status_id',
#  'flag_id',
#  'design_id',
#  'category_id',
#  'demolition_country_id',
#  'market_segment_id',
#  'exnames',
#  'me_builder',
#  'me_design',
#  'me_model',
#  'me_kw_total',
#  'me_hp',
#  'me_rpm',
#  'ae_number',
#  'last_dd_date',
#  'next_dd_date',
#  'last_ss_date',
#  'next_ss_date',
#  'class_society',
#  'cranes_type',
#  'cranes_number',
#  'cranes_swl',
#  'cranes_outreach',
#  'cranes_position',
#  'hold_details',
#  'hatches_details',
#  'private_comments',
#  'private_tags',
#  'conversion_date',
#  'private_notes']

# %%
for c in characteristics.columns:
    print(characteristics[c].value_counts())
# Out:
# id
# 83576     1
# 203901    1
# 203905    1
# 203906    1
# 204691    1
#          ..
# 150414    1
# 150415    1
# 150416    1
# 150417    1
# 218431    1
# Name: count, Length: 14757, dtype: int64
# imo
# 9122590    1
# 9942184    1
# 9942213    1
# 9942201    1
# 9959747    1
#           ..
# 9842504    1
# 9842516    1
# 9842528    1
# 9842530    1
# 1018080    1
# Name: count, Length: 14757, dtype: int64
# axs_notes_dry
#                                                                                                                                                                                                                117
# Standard Vessel Type for calculations only                                                                                                                                                                     114
# Coal Carrier                                                                                                                                                                                                    94
# <br />\n                                                                                                                                                                                                        56
# - Great Lakes Service -                                                                                                                                                                                         53
#                                                                                                                                                                                                               ...
# Cement Holes Fitted :<br />\n2 sets at each hatch of 700mm diam<br />\n                                                                                                                                          1
# <br />\nVessel has 2 cement holes on each hatchcover with a diameter of 700.0 mm each<br />\n                                                                                                                    1
# <br />\n - Vessel has 2 cement holes on each hatchcover with a <br />\n diameter of 447.8 MM each <br />\n - Vessel has 2 grain holes on each hatchcover with a <br />\n diameter of 847.8 MM each <br />\n      1
# Semi Open Hatch/Box Shaped<br />\n Hatch Size<br />\n Hatch No.1 8.80 x 25.50 / 16.00<br />\n                                                                                                                    1
# river-sea<br />\n                                                                                                                                                                                                1
# Name: count, Length: 1527, dtype: int64
# name
# HANTONG SHI (TBA)        32
# CSSC CHENGXI (TBA)       30
# NEW DAYANG (TBA)         18
# HENGLI DALIAN (TBA)      16
# JIANGSU QINFENG (TBA)    15
#                          ..
# CASSIOPEIA OCEAN          1
# ORMOS                     1
# GREEN K-MAX 1             1
# GREEN K-MAX 2             1
# TALENT DORIS              1
# Name: count, Length: 14286, dtype: int64
# type
# Bulk carrier    14741
# Other               9
# MPP                 7
# Name: count, dtype: int64
# subtype
# Bulk Carrier                     13538
# Cement Carrier                     364
# Ore Carrier                        284
# Wood Chips Carrier                 178
# Self Discharging Bulk Carrier      162
# Aggregates Carrier                 103
# Wood Pulp Carrier                   60
# Limestone Carrier                   45
# Bulker - Great Lakes Only            7
# General Cargo Ship                   6
# Livestock Carrier                    6
# Landing craft                        2
# Trans Shipment Vessel                1
# Multi-Purpose                        1
# Name: count, dtype: int64
# ship_status
# DELIVERED    13215
# ON ORDER      1398
# OTHER          117
# LAID UP         22
# REPAIRING        5
# Name: count, dtype: int64
# registered_owner
# UNDISCLOSED                          1060
# OLDENDORFF CARRIERS                    60
# RATU SHIPPING CO SA                    55
# LUCRETIA SHIPPING SA                   52
# U-MING MARINE TRANSPORT SINGAPORE      46
#                                      ...
# BLANE CORP                              1
# MAMA STRENGTH INC                       1
# AURELIA SHIPHOLDING LTD                 1
# ABY IV LLC                              1
# WEIHAI XIAO YANG LOGISTICS CO LTD       1
# Name: count, Length: 9789, dtype: int64
# ship_owner
# UNDISCLOSED                   513
# COSCO SHIPPING BULK CO        273
# STAR BULK CARRIERS CORP       160
# WISDOM MARINE LINES           141
# PACIFIC BASIN SHIPPING        117
#                              ...
# YONG SHUN INVESTMENTS           1
# CHINA MARINE SHIPPING           1
# JONMARY SHIPPING                1
# ATHENA SHIPPING CO              1
# TIANJIN TONG YANG SHIPPING      1
# Name: count, Length: 2776, dtype: int64
# tc_operator
# OLDENDORFF CARRIERS           606
# UNCOMMITTED                   558
# COSCO SHIPPING BULK CO        275
# STAR BULK CARRIERS CORP       159
# WISDOM MARINE LINES           136
#                              ...
# YALE GROUP                      1
# JASMINE SHIPPING                1
# FUJIAN HENGFENG SHIPPING        1
# UNION SHIPPING-HK               1
# TIANJIN TONG YANG SHIPPING      1
# Name: count, Length: 2801, dtype: int64
# beneficial_owner
# UNDISCLOSED                        594
# CHINA COSCO SHIPPING               391
# CHINA MERCHANTS GROUP              181
# CHINA DEVELOPMENT BANK             175
# MITSUI & CO                        150
#                                   ...
# TANGSHAN YINGSHI SM                  1
# NINGBO NINGDIAN SHIPPING             1
# JIANGSU RONGSHENG SHIPPING           1
# ZHEJIANG JIAHONG OCEAN SHIPPING      1
# HONG KONG SANLI SHIPPING             1
# Name: count, Length: 2454, dtype: int64
# flag
# Panama              2961
# Liberia             2418
# Marshall Islands    2165
# China               1440
# Hong Kong           1005
#                     ...
# Maldives               1
# Gabon                  1
# Ethiopia               1
# Dominica               1
# Bulgaria               1
# Name: count, Length: 100, dtype: int64
# built
# 0000-00-00    117
# 2025-01-10     71
# 2025-12-10     60
# 2025-06-10     59
# 2026-03-10     59
#              ...
# 2017-07-05      1
# 2018-03-23      1
# 2016-06-13      1
# 2016-08-18      1
# 2018-12-21      1
# Name: count, Length: 5702, dtype: int64
# demolition_date
# 0000-00-00    14757
# Name: count, dtype: int64
# dwt
# 82000     204
# 63500     122
# 64000     116
# 210000     57
# 40000      48
#          ...
# 81856       1
# 80979       1
# 81018       1
# 84769       1
# 9535        1
# Name: count, Length: 9908, dtype: int64
# summer_fresh_water_dwt
# 0         9609
# 93237       54
# 33224       52
# 181429      44
# 95721       41
#           ...
# 63670        1
# 63614        1
# 60511        1
# 64275        1
# 21149        1
# Name: count, Length: 1116, dtype: int64
# winter_salt_water_dwt
# 0        6091
# 90730      53
# 59624      52
# 32263      52
# 79672      49
#          ...
# 49440       1
# 48829       1
# 48996       1
# 48337       1
# 20461       1
# Name: count, Length: 2470, dtype: int64
# tropical_salt_water_dwt
# 0         6854
# 95744       53
# 34183       52
# 186109      44
# 186074      43
#           ...
# 65197        1
# 61868        1
# 65742        1
# 62144        1
# 21841        1
# Name: count, Length: 2136, dtype: int64
# tropical_fresh_water_dwt
# 0         9969
# 95691       54
# 34164       52
# 185994      44
# 98180       41
#           ...
# 64903        1
# 64825        1
# 67963        1
# 67953        1
# 22556        1
# Name: count, Length: 1015, dtype: int64
# lbp
# 217.00    572
# 185.60    533
# 222.00    519
# 195.00    465
# 182.00    464
#          ...
# 176.97      1
# 248.74      1
# 181.75      1
# 179.75      1
# 175.54      1
# Name: count, Length: 1097, dtype: int64
# loa
# 189.990    1304
# 229.000    1289
# 199.900    1034
# 225.000     666
# 228.990     479
#            ...
# 212.750       1
# 210.010       1
# 184.400       1
# 193.015       1
# 133.800       1
# Name: count, Length: 1184, dtype: int64
# beam
# 32.26    5090
# 45.00     901
# 32.24     896
# 30.00     703
# 50.00     549
#          ...
# 31.40       1
# 28.35       1
# 29.99       1
# 26.94       1
# 16.98       1
# Name: count, Length: 532, dtype: int64
# draft
# 13.300    713
# 14.450    590
# 18.300    332
# 10.500    324
# 12.800    307
#          ...
# 11.010      1
# 9.940       1
# 11.070      1
# 10.414      1
# 6.930       1
# Name: count, Length: 1442, dtype: int64
# winter_salt_water_draft
# 0.000     6099
# 12.530     404
# 14.130     297
# 13.020     284
# 14.150     257
#           ...
# 10.750       1
# 11.080       1
# 10.900       1
# 9.480        1
# 12.451       1
# Name: count, Length: 454, dtype: int64
# tropical_salt_water_draft
# 0.00     6860
# 13.07     310
# 14.73     267
# 14.75     233
# 10.02     227
#          ...
# 12.62       1
# 13.36       1
# 11.20       1
# 11.80       1
# 9.41        1
# Name: count, Length: 441, dtype: int64
# summer_fresh_water_draft
# 0.00     9562
# 14.76     250
# 10.04     219
# 14.78     219
# 13.09     171
#          ...
# 18.50       1
# 9.79        1
# 13.04       1
# 10.23       1
# 10.62       1
# Name: count, Length: 319, dtype: int64
# tropical_fresh_water_draft
# 0.000     9968
# 10.240     204
# 15.080     184
# 15.060     184
# 13.360     153
#           ...
# 14.690       1
# 13.970       1
# 14.891       1
# 13.300       1
# 12.500       1
# Name: count, Length: 297, dtype: int64
# depth
# 18.500    866
# 18.000    777
# 20.050    761
# 15.000    654
# 20.000    510
#          ...
# 20.101      1
# 20.264      1
# 20.095      1
# 20.063      1
# 16.250      1
# Name: count, Length: 390, dtype: int64
# tpc
# 0.00      1017
# 58.80      410
# 61.40      377
# 62.30      304
# 72.00      301
#           ...
# 60.48        1
# 62.15        1
# 64.76        1
# 160.00       1
# 22.60        1
# Name: count, Length: 1429, dtype: int64
# winter_salt_water_tpc
# 0.00     10720
# 58.70      198
# 48.50      110
# 39.50      104
# 61.40       97
#          ...
# 48.85        1
# 49.65        1
# 48.70        1
# 65.20        1
# 35.76        1
# Name: count, Length: 488, dtype: int64
# tropical_salt_water_tpc
# 0.00     11232
# 58.90      176
# 61.50      129
# 48.70      113
# 39.70       95
#          ...
# 51.90        1
# 53.80        1
# 50.58        1
# 51.30        1
# 36.06        1
# Name: count, Length: 444, dtype: int64
# summer_fresh_water_tpc
# 0.00     12676
# 61.50       66
# 58.90       66
# 48.70       64
# 57.40       52
#          ...
# 50.90        1
# 69.90        1
# 49.80        1
# 53.56        1
# 36.07        1
# Name: count, Length: 251, dtype: int64
# tropical_fresh_water_tpc
# 0.00     12831
# 48.80       81
# 60.00       74
# 61.50       69
# 59.00       53
#          ...
# 66.95        1
# 57.62        1
# 56.80        1
# 66.30        1
# 36.17        1
# Name: count, Length: 220, dtype: int64
# air_draft
# 0.00     14507
# 35.00       11
# 37.80       10
# 33.80        6
# 57.75        6
#          ...
# 33.78        1
# 45.55        1
# 42.63        1
# 42.22        1
# 38.50        1
# Name: count, Length: 159, dtype: int64
# gt
# 44000    191
# 0        115
# 33044     96
# 32987     74
# 36000     70
#         ...
# 29439      1
# 30719      1
# 29761      1
# 29970      1
# 5180       1
# Name: count, Length: 4734, dtype: int64
# suez_gt
# 0.0        10881
# 33919.9       39
# 92610.3       26
# 93198.9       24
# 34258.0       20
#            ...
# 30507.0        1
# 39505.0        1
# 30987.0        1
# 30940.7        1
# 18179.0        1
# Name: count, Length: 2122, dtype: int64
# panama_gt
# 0.0        14460
# 30046.0        6
# 36414.0        6
# 27986.0        5
# 27319.0        5
#            ...
# 10985.0        1
# 25793.0        1
# 32415.0        1
# 27390.0        1
# 14876.0        1
# Name: count, Length: 231, dtype: int64
# nt
# 0        436
# 21000    292
# 27000    199
# 19231    173
# 28000    157
#         ...
# 18258      1
# 18152      1
# 18541      1
# 18522      1
# 3941       1
# Name: count, Length: 3597, dtype: int64
# suez_nt
# 0.0        10676
# 31285.0       27
# 87489.3       24
# 31013.0       21
# 19066.0       16
#            ...
# 42418.5        1
# 42152.0        1
# 41713.8        1
# 39267.0        1
# 14521.0        1
# Name: count, Length: 2422, dtype: int64
# panama_nt
# 0.0        11565
# 27390.0       38
# 30213.0       23
# 27319.0       21
# 29666.0       18
#            ...
# 35216.6        1
# 26828.0        1
# 26820.0        1
# 32037.0        1
# 14063.0        1
# Name: count, Length: 1512, dtype: int64
# ldt
# 14246    210
# 0        132
# 11893    126
# 11959    116
# 27889     57
#         ...
# 10978      1
# 14364      1
# 13379      1
# 13439      1
# 3340       1
# Name: count, Length: 6953, dtype: int64
# shipyard
# OSHIMA OSHIMA         601
# TSUNEISHI CEBU        414
# IMABARI MARUGAME      312
# HANTONG SHI           297
# TSUNEISHI ZHOUSHAN    280
#                      ...
# ZHEJIANG NINGHAI        1
# YUKSEL MAKINA           1
# YUEQING SHUNHANG        1
# WENLING OCEAN           1
# SEKO HI                 1
# Name: count, Length: 612, dtype: int64
# second_shipyard
# HOLLAND    1
# Name: count, dtype: int64
# hull_number
# (TBA)           562
# NONE             68
# 1004              9
# 1006              9
# 1005              9
#                ...
# SS-288            1
# SS-287            1
# MC6001            1
# YZJ2015-2099      1
# 3E4617            1
# Name: count, Length: 10122, dtype: int64
# design
# SDARI Dolphin 64            535
# SDARI Dolphin 57            448
# TESS 82                     388
# SDARI 82                    255
# IS NEW I-STAR               245
#                            ...
# SHIN KURUSHIMA 33 (OHBS)      1
# Sietas 96                     1
# EWB 600                       1
# CSDC BC180K (Jinhai)          1
# Bodewes Trader 7575           1
# Name: count, Length: 220, dtype: int64
# total_main_engines
# 1    13223
# 0     1376
# 2      150
# 4        6
# 3        2
# Name: count, dtype: int64
# bow_thruster
# Y    174
# N     14
# Name: count, dtype: int64
# stern_thruster
# Y    17
# Name: count, dtype: int64
# geared
# Y    7576
# N    6814
# Name: count, dtype: int64
# grabs_number
# 0    10824
# 4     3678
# 3      190
# 2       44
# 5       17
# 6        2
# 7        1
# 8        1
# Name: count, dtype: int64
# grabs_capacity
# 0.00     10902
# 12.00     2254
# 14.00      352
# 15.00      319
# 10.00      298
# 12.50      154
# 8.00       137
# 13.00      135
# 13.50       64
# 20.00       33
# 18.00       25
# 9.00        12
# 16.00       10
# 15.30        8
# 18.50        8
# 14.50        6
# 11.00        6
# 6.00         4
# 15.50        3
# 22.50        3
# 17.00        3
# 11.50        2
# 7.50         2
# 6.30         2
# 24.00        2
# 12.60        2
# 15.20        1
# 7.00         1
# 19.00        1
# 12.30        1
# 11.30        1
# 10.80        1
# 30.00        1
# 25.00        1
# 8.50         1
# 4.50         1
# 14.75        1
# Name: count, dtype: int64
# total_decks
# 1    9090
# 0    5630
# 2      37
# Name: count, dtype: int64
# grain
# 71634.0     354
# 97000.0     211
# 97250.0     116
# 78000.0     114
# 201243.0    113
#            ...
# 70867.0       1
# 68023.0       1
# 72346.0       1
# 69384.0       1
# 14529.0       1
# Name: count, Length: 3130, dtype: int64
# bale
# 0         2529
# 90784      510
# 68200      422
# 200000     400
# 73680      256
#           ...
# 59665        1
# 56666        1
# 59550        1
# 16987        1
# 20050        1
# Name: count, Length: 1762, dtype: int64
# holds
# 5     6908
# 7     3734
# 9     1806
# 0      854
# 4      414
# 6      413
# 2      275
# 3      190
# 1      114
# 8       43
# 10       3
# 12       2
# 13       1
# Name: count, dtype: int64
# hatches
# 5     6849
# 7     3722
# 9     1822
# 0      974
# 6      392
# 4      378
# 2      236
# 3      180
# 1      104
# 8       28
# 17      14
# 24      10
# 10       8
# 20       7
# 22       5
# 25       5
# 18       4
# 36       4
# 23       3
# 21       2
# 37       2
# 16       2
# 15       2
# 14       2
# 19       1
# 12       1
# Name: count, dtype: int64
# active
# onMarket    14757
# Name: count, dtype: int64
# call_sign
# (TBA)     5
# 3FYB9     2
# YCXY2     2
# V7IQ8     2
# CQKO      2
#          ..
# D5TV5     1
# D5QJ4     1
# 5BAB5     1
# HPYZ      1
# 3E6923    1
# Name: count, Length: 13174, dtype: int64
# open_hatches
# OHBS    641
# BOX     364
# Y       246
# N         2
# Name: count, dtype: int64
# lakes_fitted
# Y    269
# N     96
# Name: count, dtype: int64
# logs_fitted
# Y    1143
# N     411
# Name: count, dtype: int64
# ahl_fitted
# Y    3907
# N      43
# Name: count, dtype: int64
# co2_fitted
# Y    4385
# N     863
# Name: count, dtype: int64
# keel_laying_date
# 0000-00-00    9779
# 2015-12-25      81
# 2015-12-28      50
# 2015-12-22      45
# 2015-12-29      41
#               ...
# 2023-06-20       1
# 2022-10-31       1
# 2024-03-12       1
# 2022-11-11       1
# 2024-01-11       1
# Name: count, Length: 2458, dtype: int64
# launching_date
# 0000-00-00    8941
# 2014-12-23       9
# 2015-06-02       7
# 2016-01-15       6
# 2011-11-09       6
#               ...
# 2015-11-16       1
# 2015-03-13       1
# 2016-01-31       1
# 2015-07-23       1
# 2024-09-18       1
# Name: count, Length: 3861, dtype: int64
# reported_date
# 2008-01-10    360
# 2007-01-10    254
# 0000-00-00    254
# 2007-12-10    214
# 2007-10-10    188
#              ...
# 1975-12-10      1
# 1976-06-10      1
# 1976-01-10      1
# 1976-03-10      1
# 1990-10-10      1
# Name: count, Length: 606, dtype: int64
# cancelled_date
# 0000-00-00    14757
# Name: count, dtype: int64
# mmsi
# 0            1494
# 312663000       2
# 374518000       2
# 352003715       2
# 372060000       2
#              ...
# 477333100       1
# 477131700       1
# 477153100       1
# 477153300       1
# 352002831       1
# Name: count, Length: 13260, dtype: int64
# ice_class
# IC             373
# Category II    283
# IA              49
# IB              49
# N               15
# IA Super         3
# Name: count, dtype: int64
# ballast_water
# 0         14742
# 57014         2
# 54946         1
# 66151         1
# 87195         1
# 66040         1
# 113223        1
# 58439         1
# 65435         1
# 22018         1
# 34837         1
# 22045         1
# 15377         1
# 15670         1
# 8650          1
# Name: count, dtype: int64
# shipbuilding_group
# NIHON SHIPYARD                                      1736
# TSUNEISHI SHIPBUILDING                              1074
# CHINA STATE SHIPBUILDING CORP (CSSC)                1006
# COSCO SHIPPING HEAVY INDUSTRY                        719
# NAMURA SHIPBUILDING                                  566
# CHINA SHIPBUILDING INDUSTRY CORP (CSIC)              483
# HD KSOE                                              373
# MITSUI E&S                                           361
# YANGZIJIANG SHIPBUILDING GROUP                       351
# SHIN KURUSHIMA DOCKYARD                              326
# SANOYAS SHIPBUILDING                                 228
# ZHEJIANG SHIPBUILDING GROUP                          211
# CHINA MERCHANTS HEAVY INDUSTRY (CMHI)                171
# SAIKI HEAVY INDUSTRIES                               143
# SPP SHIPBUILDING                                     109
# KAWASAKI HEAVY INDUSTRIES                            104
# SINOTRANS & CSC GROUP                                 95
# SHANDONG HUIYANG GROUP                                59
# HNA GROUP                                             57
# KANASASHI HI                                          49
# ZHOUJI GROUP                                          43
# SUMITOMO HEAVY INDUSTRIES                             38
# NAIKAI ZOSEN CORPORATION                              37
# JAPAN MARINE UNITED (JMU)                             33
# JIANLONG GROUP                                        29
# AVIC GROUP                                            26
# BESTWAY MARINE & ENERGY TECHNOLOGY                    21
# CSSC OFFSHORE & MARINE ENGINEERING GROUP (COMEC)      16
# MITSUBISHI HEAVY INDUSTRY                             14
# CHINA INTERNATIONAL MARINE CONTAINERS (CIMC)           9
# ULJANIK                                                6
# KUOK SINGAPORE                                         5
# DAMEN SHIPYARDS GROUP                                  3
# KEPPEL O&M                                             1
# VEKA GROUP                                             1
# Name: count, dtype: int64
# Series([], Name: count, dtype: int64)
# pool
# TMA BULK    1
# Name: count, dtype: int64
# Series([], Name: count, dtype: int64)
# Series([], Name: count, dtype: int64)
# Series([], Name: count, dtype: int64)
# Series([], Name: count, dtype: int64)
# dual_fuel
# Ammonia Ready                    111
# LNG Ready                         75
# LNG                               71
# Methanol                          61
# Hybrid Battery                    27
# Ammonia                           24
# Methanol Ready                    22
# Rotor Sails                       15
# LNG,Ammonia Ready                 12
# LPG                               10
# Methanol,Ammonia Ready             8
# Hybrid Battery,Methanol Ready      7
# LNG Ready,Ammonia Ready            2
# Methanol,Rotor Sails               2
# LNG,Hybrid Battery                 1
# Name: count, dtype: int64
# scrubbers
# Y    1649
# N      38
# Name: count, dtype: int64
# bwts
# Y    4331
# N       2
# Name: count, dtype: int64
# ordering_company
# UNDISCLOSED               709
# CHINA COSCO SHIPPING      334
# NISSEN KAIUN              246
# NYK                       243
# MOL                       200
#                          ...
# SAITO KAIUN                 1
# LIBERTY DI NAVIGAZIONE      1
# KOYO LINE                   1
# OSAKA FLEET                 1
# KOWA KAIUN                  1
# Name: count, Length: 1784, dtype: int64
# demolition_country
# China         2
# Bangladesh    1
# India         1
# Name: count, dtype: int64
# full_ballast_speed
# 14.00    5198
# 13.00    2128
# 14.50    1942
# 13.50    1603
# 15.00    1189
#          ...
# 16.70       1
# 14.03       1
# 15.48       1
# 16.20       1
# 9.00        1
# Name: count, Length: 96, dtype: int64
# full_laden_speed
# 13.50    3612
# 14.00    3534
# 13.00    2740
# 14.50     735
# 12.00     581
#          ...
# 13.04       1
# 12.45       1
# 14.92       1
# 17.70       1
# 15.79       1
# Name: count, Length: 110, dtype: int64
# eco_ballast_speed
# 12.50    4314
# 12.00    4144
# 13.00    2006
# 12.75     761
# 13.50     503
#          ...
# 15.25       1
# 13.64       1
# 11.95       1
# 8.50        1
# 13.12       1
# Name: count, Length: 94, dtype: int64
# eco_laden_speed
# 12.00    5770
# 11.50    1741
# 11.60    1428
# 12.50    1139
# 11.00    1034
#          ...
# 9.80        1
# 13.75       1
# 10.09       1
# 11.06       1
# 9.90        1
# Name: count, Length: 89, dtype: int64
# full_ballast_hsfo
# 28.00    396
# 30.00    386
# 29.00    374
# 27.00    320
# 32.00    309
#         ...
# 31.94      1
# 37.90      1
# 39.70      1
# 32.27      1
# 12.47      1
# Name: count, Length: 1819, dtype: int64
# full_laden_hsfo
# 29.00    463
# 30.00    399
# 31.00    350
# 32.00    349
# 28.00    322
#         ...
# 41.92      1
# 38.34      1
# 38.35      1
# 33.28      1
# 15.98      1
# Name: count, Length: 2097, dtype: int64
# eco_ballast_hsfo
# 23.00    460
# 25.00    437
# 24.00    418
# 21.00    403
# 22.00    401
#         ...
# 22.42      1
# 23.17      1
# 21.53      1
# 19.03      1
# 12.40      1
# Name: count, Length: 1676, dtype: int64
# eco_laden_hsfo
# 25.00    491
# 24.00    478
# 23.00    434
# 20.00    376
# 26.00    370
#         ...
# 24.72      1
# 23.81      1
# 25.89      1
# 24.86      1
# 12.65      1
# Name: count, Length: 1865, dtype: int64
# port_load_hsfo
# 5.00    1654
# 4.50    1151
# 5.50     937
# 4.00     860
# 6.00     788
#         ...
# 6.75       1
# 5.72       1
# 5.02       1
# 7.35       1
# 2.05       1
# Name: count, Length: 603, dtype: int64
# in_port_idle_hsfo
# 3.00    1934
# 2.50    1426
# 3.50    1418
# 4.00     620
# 2.00     588
#         ...
# 5.11       1
# 2.73       1
# 5.47       1
# 3.18       1
# 1.09       1
# Name: count, Length: 412, dtype: int64
# full_ballast_ae_lsmgo
# 0.20    7645
# 0.10    5474
# 0.50     370
# 0.30     212
# 0.05     126
#         ...
# 9.00       1
# 0.95       1
# 0.14       1
# 0.56       1
# 0.65       1
# Name: count, Length: 66, dtype: int64
# full_laden_ae_lsmgo
# 0.20     7555
# 0.10     5476
# 0.50      368
# 0.30      213
# 0.05      126
#          ...
# 41.00       1
# 12.80       1
# 59.00       1
# 9.00        1
# 0.65        1
# Name: count, Length: 107, dtype: int64
# eco_ballast_ae_lsmgo
# 0.20    7603
# 0.10    5526
# 0.50     351
# 0.30     206
# 0.05     126
#         ...
# 0.29       1
# 3.60       1
# 8.00       1
# 0.11       1
# 0.65       1
# Name: count, Length: 67, dtype: int64
# eco_laden_ae_lsmgo
# 0.20    7603
# 0.10    5519
# 0.50     350
# 0.30     207
# 0.05     126
#         ...
# 3.60       1
# 0.28       1
# 8.00       1
# 0.11       1
# 0.65       1
# Name: count, Length: 69, dtype: int64
# port_load_ae_lsmgo
# 0.20    7598
# 0.10    4625
# 0.50     636
# 0.30     436
# 0.40     150
#         ...
# 3.70       1
# 7.60       1
# 4.70       1
# 5.25       1
# 0.65       1
# Name: count, Length: 90, dtype: int64
# in_port_idle_ae_lsmgo
# 0.20    7821
# 0.10    4706
# 0.50     598
# 0.30     332
# 1.00     163
#         ...
# 8.00       1
# 0.28       1
# 3.60       1
# 0.13       1
# 0.65       1
# Name: count, Length: 75, dtype: int64
# full_ballast_lsmgo
# 28.00    396
# 30.00    386
# 29.00    374
# 27.00    320
# 32.00    309
#         ...
# 37.90      1
# 39.70      1
# 32.27      1
# 32.49      1
# 12.47      1
# Name: count, Length: 1818, dtype: int64
# full_laden_lsmgo
# 29.00    465
# 30.00    399
# 31.00    350
# 32.00    349
# 28.00    323
#         ...
# 41.92      1
# 38.34      1
# 38.35      1
# 33.28      1
# 15.98      1
# Name: count, Length: 2098, dtype: int64
# eco_ballast_lsmgo
# 23.00    460
# 25.00    437
# 24.00    418
# 21.00    403
# 22.00    401
#         ...
# 22.65      1
# 22.42      1
# 23.17      1
# 21.53      1
# 12.40      1
# Name: count, Length: 1677, dtype: int64
# eco_laden_lsmgo
# 25.00    492
# 24.00    477
# 23.00    435
# 20.00    377
# 26.00    370
#         ...
# 24.48      1
# 24.72      1
# 23.81      1
# 25.89      1
# 12.65      1
# Name: count, Length: 1866, dtype: int64
# port_load_lsmgo
# 5.00    1652
# 4.50    1152
# 5.50     936
# 4.00     860
# 6.00     788
#         ...
# 6.75       1
# 5.72       1
# 5.02       1
# 7.35       1
# 2.05       1
# Name: count, Length: 605, dtype: int64
# in_port_idle_lsmgo
# 3.00    1935
# 2.50    1425
# 3.50    1417
# 4.00     620
# 2.00     586
#         ...
# 5.11       1
# 2.73       1
# 5.47       1
# 3.18       1
# 1.09       1
# Name: count, Length: 413, dtype: int64
# fresh_water
# 0.00      6810
# 488.00     132
# 294.84     100
# 674.00      94
# 400.00      89
#           ...
# 518.21       1
# 933.64       1
# 933.96       1
# 668.00       1
# 172.10       1
# Name: count, Length: 1595, dtype: int64
# constants
# 0      7128
# 300    1695
# 350    1299
# 250     729
# 400     519
#        ...
# 356       1
# 541       1
# 301       1
# 155       1
# 194       1
# Name: count, Length: 221, dtype: int64
# full_laden_vlsfo
# 29.00    465
# 30.00    399
# 31.00    350
# 32.00    349
# 28.00    323
#         ...
# 41.92      1
# 38.34      1
# 38.35      1
# 33.28      1
# 15.98      1
# Name: count, Length: 2098, dtype: int64
# full_ballast_vlsfo
# 28.00    396
# 30.00    386
# 29.00    374
# 27.00    320
# 32.00    309
#         ...
# 37.90      1
# 39.70      1
# 32.27      1
# 32.49      1
# 12.47      1
# Name: count, Length: 1818, dtype: int64
# eco_laden_vlsfo
# 25.00    492
# 24.00    477
# 23.00    435
# 20.00    377
# 26.00    370
#         ...
# 24.72      1
# 23.81      1
# 25.89      1
# 24.86      1
# 12.65      1
# Name: count, Length: 1865, dtype: int64
# eco_ballast_vlsfo
# 23.00    460
# 25.00    437
# 24.00    418
# 21.00    403
# 22.00    401
#         ...
# 22.42      1
# 23.17      1
# 21.53      1
# 19.03      1
# 12.40      1
# Name: count, Length: 1676, dtype: int64
# port_load_vlsfo
# 5.00    1652
# 4.50    1152
# 5.50     937
# 4.00     860
# 6.00     788
#         ...
# 6.75       1
# 5.72       1
# 5.02       1
# 7.35       1
# 2.05       1
# Name: count, Length: 605, dtype: int64
# in_port_idle_vlsfo
# 3.00    1935
# 2.50    1425
# 3.50    1417
# 4.00     620
# 2.00     587
#         ...
# 5.11       1
# 2.73       1
# 5.47       1
# 3.18       1
# 1.09       1
# Name: count, Length: 413, dtype: int64
# eco_2_ballast_speed
# 11.00    4218
# 10.50    2065
# 12.00    1463
# 10.00    1116
# 11.50    1054
#          ...
# 12.45       1
# 11.47       1
# 11.74       1
# 9.45        1
# 15.00       1
# Name: count, Length: 151, dtype: int64
# eco_2_laden_speed
# 10.00    1970
# 11.00    1917
# 10.50    1744
# 12.00    1080
# 9.50     1050
#          ...
# 11.66       1
# 8.91        1
# 12.84       1
# 11.05       1
# 16.20       1
# Name: count, Length: 162, dtype: int64
# eco_2_ballast_hsfo
# 16.00    112
# 21.00    107
# 20.00    104
# 16.04    103
# 12.89    103
#         ...
# 23.25      1
# 26.10      1
# 33.29      1
# 34.00      1
# 20.47      1
# Name: count, Length: 2171, dtype: int64
# eco_2_laden_hsfo
# 21.00    153
# 20.00    130
# 16.00    115
# 20.50     94
# 23.00     94
#         ...
# 19.16      1
# 17.73      1
# 28.73      1
# 36.22      1
# 8.69       1
# Name: count, Length: 2361, dtype: int64
# eco_2_ballast_ae_lsmgo
# 0.00    13587
# 0.10      765
# 0.20      348
# 0.30       20
# 0.15        8
# 0.50        8
# 0.07        6
# 0.05        5
# 0.16        2
# 0.09        2
# 0.08        2
# 2.00        1
# 0.03        1
# 0.70        1
# 0.40        1
# Name: count, dtype: int64
# eco_2_laden_ae_lsmgo
# 0.00    13581
# 0.10      769
# 0.20      350
# 0.30       20
# 0.15        8
# 0.50        8
# 0.07        6
# 0.05        5
# 0.16        2
# 0.09        2
# 0.08        2
# 2.00        1
# 0.03        1
# 0.70        1
# 0.40        1
# Name: count, dtype: int64
# eco_2_ballast_lsmgo
# 16.00    112
# 21.00    107
# 20.00    104
# 16.04    103
# 12.89    103
#         ...
# 23.25      1
# 26.10      1
# 33.29      1
# 34.00      1
# 20.47      1
# Name: count, Length: 2171, dtype: int64
# eco_2_laden_lsmgo
# 21.00    153
# 20.00    130
# 16.00    115
# 20.50     94
# 23.00     94
#         ...
# 19.16      1
# 17.73      1
# 28.73      1
# 36.22      1
# 8.69       1
# Name: count, Length: 2361, dtype: int64
# eco_2_ballast_vlsfo
# 16.00    112
# 21.00    107
# 20.00    104
# 16.04    103
# 12.89    103
#         ...
# 23.25      1
# 26.10      1
# 33.29      1
# 34.00      1
# 20.47      1
# Name: count, Length: 2171, dtype: int64
# eco_2_laden_vlsfo
# 21.00    153
# 20.00    130
# 16.00    115
# 20.50     94
# 23.00     94
#         ...
# 19.16      1
# 17.73      1
# 28.73      1
# 36.22      1
# 8.69       1
# Name: count, Length: 2361, dtype: int64
# canal_hsfo
# 0.00     4095
# 3.00     1932
# 2.50     1420
# 3.50     1412
# 4.00      620
#          ...
# 28.00       1
# 6.25        1
# 6.70        1
# 5.90        1
# 0.90        1
# Name: count, Length: 108, dtype: int64
# canal_ae_lsmgo
# 0.00    6703
# 0.10    3980
# 0.20    2140
# 0.50     538
# 0.30     307
#         ...
# 0.13       1
# 2.90       1
# 0.29       1
# 5.50       1
# 5.80       1
# Name: count, Length: 66, dtype: int64
# canal_lsmgo
# 0.00     4096
# 3.00     1932
# 2.50     1419
# 3.50     1411
# 4.00      620
#          ...
# 28.00       1
# 6.25        1
# 6.70        1
# 5.90        1
# 0.90        1
# Name: count, Length: 109, dtype: int64
# canal_vlsfo
# 0.00     4096
# 3.00     1932
# 2.50     1419
# 3.50     1411
# 4.00      620
#          ...
# 28.00       1
# 6.25        1
# 6.70        1
# 5.90        1
# 0.90        1
# Name: count, Length: 109, dtype: int64
# port_disch_hsfo
# 5.00    1654
# 4.50    1151
# 5.50     937
# 4.00     860
# 6.00     788
#         ...
# 6.75       1
# 5.72       1
# 5.02       1
# 7.35       1
# 2.05       1
# Name: count, Length: 603, dtype: int64
# port_disch_ae_lsmgo
# 0.20    7598
# 0.10    4625
# 0.50     636
# 0.30     436
# 0.40     150
#         ...
# 3.70       1
# 7.60       1
# 4.70       1
# 5.25       1
# 0.65       1
# Name: count, Length: 90, dtype: int64
# port_disch_lsmgo
# 5.00    1652
# 4.50    1152
# 5.50     936
# 4.00     860
# 6.00     788
#         ...
# 6.75       1
# 5.72       1
# 5.02       1
# 7.35       1
# 2.05       1
# Name: count, Length: 605, dtype: int64
# port_disch_vlsfo
# 5.00    1652
# 4.50    1152
# 5.50     937
# 4.00     860
# 6.00     788
#         ...
# 6.75       1
# 5.72       1
# 5.02       1
# 7.35       1
# 2.05       1
# Name: count, Length: 605, dtype: int64
# hsfo_tank
# 0.0       5641
# 2.0        608
# 1.0        496
# 4.0        288
# 1839.0     120
#           ...
# 1856.0       1
# 3061.0       1
# 2696.0       1
# 2558.0       1
# 183.0        1
# Name: count, Length: 2123, dtype: int64
# lsmgo_tank
# 0.00      10768
# 177.00       52
# 133.00       49
# 200.00       36
# 120.00       32
#           ...
# 542.00        1
# 542.89        1
# 87.70         1
# 546.00        1
# 190.65        1
# Name: count, Length: 1194, dtype: int64
# vlsfo_tank
# 0    14757
# Name: count, dtype: int64
# hatches_type
# Side Rolling                                                                             516
# Side rolling                                                                             390
# Folding                                                                                  327
# Folding Type                                                                             226
# Folding type                                                                             213
#                                                                                         ...
# Weathertight double skin folding with flat top and outplaced hydraulic cylinders           1
# Macgregor end folding steel covers - hydraulically operated                                1
# Electrohydraulic Folding Type, Weather Steel Cover On Upper Deck                           1
# Folding, Weathertight steel hatch cover on upper deck operated by hydraulic cylinder       1
# Booby hatch covers                                                                         1
# Name: count, Length: 2807, dtype: int64
# tts
#  25.00                                                                         370
#  20.00                                                                         367
# <br />\n 1/3/5 : 25.00<br />\n 2/4 : 20.00                                     285
#  15.00                                                                         114
# <br />\n 1/3/5 : 20.00<br />\n 2/4 : 15.00                                      74
#                                                                               ...
# <br />\n 1 : 24.16<br />\n 2/4 : 18.40<br />\n 3 :24.34<br />\n 5 : 24.36        1
# <br />\n 1 = 24.16<br />\n 2/4 = 18.40<br />\n 3 = 24.34 <br />\n 5 = 24.36      1
# <br />\n 1/5 : 23.00<br />\n 3 : 24.00<br />\n 2/4 : 15.00                       1
# <br />\n 1 = 24.10<br />\n 2/4 = 18.40<br />\n 3/5 = 24.30                       1
# <br />\n 1 : 10.50<br />\n 2 : 9.99<br />\n 3 : 9.97<br />\n 4 : 10.01           1
# Name: count, Length: 2067, dtype: int64
# category
# Panamax (Dwt 68-85k)        3088
# Handy (Dwt 25-40k)          2451
# Supramax (Dwt 50-60k)       2051
# Ultramax (Dwt 60-68k)       1962
# Cape (Dwt 160-220k)         1735
# Minibulker (Dwt <25k)       1556
# Handymax (Dwt 40-50k)        839
# OverPmx (Dwt 85-100k)        615
# VLOC (Dwt 220k+)             283
# BabyCape (Dwt 100-120k)      143
# SmallCape (Dwt 120-160k)      34
# Name: count, dtype: int64
# market_segment
# dry        14749
# general        8
# Name: count, dtype: int64
# update_date
# 2024-10-01 11:16:16    875
# 2024-10-01 14:25:04    512
# 2024-12-02 18:10:43    335
# 2024-12-12 08:15:17    147
# 2024-11-12 09:53:24    133
#                       ...
# 2024-04-22 11:10:26      1
# 2024-12-23 09:25:09      1
# 2024-06-06 11:52:14      1
# 2024-10-03 12:45:16      1
# 2024-12-27 07:48:25      1
# Name: count, Length: 6539, dtype: int64
# registered_owner_id
# 17162.0     1060
# 8064.0        60
# 4397.0        55
# 3169.0        52
# 109676.0      46
#             ...
# 150917.0       1
# 152384.0       1
# 12817.0        1
# 121339.0       1
# 175610.0       1
# Name: count, Length: 9791, dtype: int64
# registered_owner_flag
# Marshall Islands        2179
# Panama                  2091
# China                   1892
# Liberia                 1408
# Hong Kong               1231
#                         ...
# Syrian Arab Republic       1
# Gibraltar                  1
# Algeria                    1
# Cook Islands               1
# Equatorial Guinea          1
# Name: count, Length: 99, dtype: int64
# registered_owner_flag_id
# 137.0    2179
# 170.0    2091
# 45.0     1892
# 124.0    1408
# 98.0     1231
#          ...
# 214.0       1
# 83.0        1
# 4.0         1
# 52.0        1
# 66.0        1
# Name: count, Length: 99, dtype: int64
# ship_owner_id
# 17162.0     513
# 16143.0     273
# 12637.0     160
# 5827.0      141
# 8494.0      117
#            ...
# 173095.0      1
# 17979.0       1
# 164994.0      1
# 170490.0      1
# 175609.0      1
# Name: count, Length: 2776, dtype: int64
# ship_owner_flag
# Greece         2949
# China          2826
# Japan          1518
# Hong Kong       841
# Singapore       724
#                ...
# Algeria           1
# Ethiopia          1
# New Zealand       1
# Seychelles        1
# Panama            1
# Name: count, Length: 88, dtype: int64
# ship_owner_flag_id
# 84.0     2949
# 45.0     2826
# 110.0    1518
# 98.0      841
# 199.0     724
#          ...
# 4.0         1
# 69.0        1
# 158.0       1
# 197.0       1
# 170.0       1
# Name: count, Length: 88, dtype: int64
# tc_operator_id
# 8064.0      606
# 16664.0     558
# 16143.0     275
# 12637.0     159
# 5827.0      136
#            ...
# 167056.0      1
# 33757.0       1
# 9945.0        1
# 139380.0      1
# 175609.0      1
# Name: count, Length: 2801, dtype: int64
# tc_operator_flag
# China         2731
# Greece        2690
# Japan         1331
# Germany        912
# Hong Kong      762
#               ...
# Iraq             1
# Algeria          1
# Seychelles       1
# Ethiopia         1
# Panama           1
# Name: count, Length: 90, dtype: int64
# tc_operator_flag_id
# 45.0     2731
# 84.0     2690
# 110.0    1331
# 81.0      912
# 98.0      762
#          ...
# 104.0       1
# 4.0         1
# 197.0       1
# 69.0        1
# 170.0       1
# Name: count, Length: 90, dtype: int64
# beneficial_owner_id
# 17162.0     594
# 16104.0     391
# 964.0       181
# 11769.0     175
# 8067.0      150
#            ...
# 171530.0      1
# 170025.0      1
# 168551.0      1
# 123271.0      1
# 170576.0      1
# Name: count, Length: 2454, dtype: int64
# beneficial_owner_flag
# China               3505
# Greece              2509
# Japan               2185
# Unknown              595
# Hong Kong            579
#                     ...
# Seychelles             1
# Algeria                1
# Papua New Guinea       1
# Ethiopia               1
# Iraq                   1
# Name: count, Length: 90, dtype: int64
# beneficial_owner_flag_id
# 45.0     3505
# 84.0     2509
# 110.0    2185
# 247.0     595
# 98.0      579
#          ...
# 197.0       1
# 4.0         1
# 171.0       1
# 69.0        1
# 104.0       1
# Name: count, Length: 90, dtype: int64
# shipyard_id
# 83149.0    601
# 83768.0    414
# 83124.0    312
# 84070.0    297
# 84059.0    280
#           ...
# 83522.0      1
# 83524.0      1
# 83526.0      1
# 85001.0      1
# 84260.0      1
# Name: count, Length: 612, dtype: int64
# shipyard_flag
# China                                     6793
# Japan                                     5594
# Korea, Republic of                        1016
# Philippines                                437
# Viet Nam                                   172
# India                                       58
# Taiwan, Province of China                   50
# Netherlands                                 44
# United States                               42
# Germany                                     27
# Turkey                                      26
# Bangladesh                                  21
# Romania                                     19
# Bulgaria                                    17
# Spain                                       17
# Denmark                                     15
# Indonesia                                   13
# Croatia                                     12
# Norway                                      12
# Canada                                      10
# Sri Lanka                                   10
# Singapore                                    8
# Brazil                                       7
# Argentina                                    7
# Hong Kong                                    6
# United Kingdom                               6
# Poland                                       5
# Italy                                        5
# Portugal                                     4
# Sweden                                       4
# Malaysia                                     4
# Finland                                      2
# Greece                                       2
# Australia                                    2
# Korea, Democratic People's Republic of       2
# Russian Federation                           2
# Ukraine                                      1
# Unknown                                      1
# Serbia                                       1
# Belgium                                      1
# Name: count, dtype: int64
# shipyard_flag_id
# 45.0     6793
# 110.0    5594
# 117.0    1016
# 174.0     437
# 239.0     172
# 101.0      58
# 215.0      50
# 155.0      44
# 233.0      42
# 81.0       27
# 225.0      26
# 19.0       21
# 181.0      19
# 34.0       17
# 206.0      17
# 59.0       15
# 102.0      13
# 55.0       12
# 165.0      12
# 39.0       10
# 207.0      10
# 199.0       8
# 31.0        7
# 11.0        7
# 98.0        6
# 232.0       6
# 176.0       5
# 108.0       5
# 177.0       4
# 212.0       4
# 133.0       4
# 73.0        2
# 84.0        2
# 14.0        2
# 116.0       2
# 182.0       2
# 230.0       1
# 247.0       1
# 196.0       1
# 22.0        1
# Name: count, dtype: int64
# second_shipyard_id
# 83018.0    1
# Name: count, dtype: int64
# second_shipyard_flag
# Netherlands    1
# Name: count, dtype: int64
# second_shipyard_flag_id
# 155.0    1
# Name: count, dtype: int64
# shipbuilding_group_id
# 136926.0    1736
# 158691.0    1074
# 12544.0     1006
# 135183.0     719
# 111602.0     566
# 125493.0     483
# 139687.0     373
# 11778.0      361
# 12907.0      351
# 140179.0     326
# 111598.0     228
# 158725.0     211
# 130635.0     171
# 125572.0     143
# 110959.0     109
# 158540.0     104
# 158712.0      95
# 111397.0      59
# 11227.0       57
# 138742.0      49
# 158726.0      43
# 158551.0      38
# 111689.0      37
# 135996.0      33
# 158722.0      29
# 158718.0      26
# 111395.0      21
# 158537.0      16
# 158723.0      14
# 11861.0        9
# 82618.0        6
# 158544.0       5
# 40421.0        3
# 114742.0       1
# 158565.0       1
# Name: count, dtype: int64
# shipbuilding_group_flag
# Japan                 4709
# China                 3296
# Korea, Republic of     482
# Croatia                  6
# Singapore                6
# Netherlands              4
# Name: count, dtype: int64
# shipbuilding_group_flag_id
# 110.0    4709
# 45.0     3296
# 117.0     482
# 55.0        6
# 199.0       6
# 155.0       4
# Name: count, dtype: int64
# Series([], Name: count, dtype: int64)
# Series([], Name: count, dtype: int64)
# Series([], Name: count, dtype: int64)
# pool_id
# 132771.0    1
# Name: count, dtype: int64
# pool_flag
# Germany    1
# Name: count, dtype: int64
# pool_flag_id
# 81.0    1
# Name: count, dtype: int64
# Series([], Name: count, dtype: int64)
# Series([], Name: count, dtype: int64)
# Series([], Name: count, dtype: int64)
# Series([], Name: count, dtype: int64)
# Series([], Name: count, dtype: int64)
# Series([], Name: count, dtype: int64)
# Series([], Name: count, dtype: int64)
# Series([], Name: count, dtype: int64)
# Series([], Name: count, dtype: int64)
# Series([], Name: count, dtype: int64)
# Series([], Name: count, dtype: int64)
# Series([], Name: count, dtype: int64)
# ordering_company_id
# 17162.0     709
# 16104.0     334
# 7002.0      246
# 6374.0      243
# 7070.0      200
#            ...
# 36947.0       1
# 11832.0       1
# 12033.0       1
# 140959.0      1
# 153812.0      1
# Name: count, Length: 1784, dtype: int64
# ordering_company_flag
# Japan                      4048
# China                      2327
# Greece                     1611
# Unknown                     722
# Hong Kong                   677
#                            ...
# Austria                       1
# Faroe Islands                 1
# New Zealand                   1
# Papua New Guinea              1
# Virgin Islands, British       1
# Name: count, Length: 78, dtype: int64
# ordering_company_flag_id
# 110.0    4048
# 45.0     2327
# 84.0     1611
# 247.0     722
# 98.0      677
#          ...
# 15.0        1
# 71.0        1
# 158.0       1
# 171.0       1
# 240.0       1
# Name: count, Length: 78, dtype: int64
# type_id
# 221    14741
# 230        9
# 223        7
# Name: count, dtype: int64
# subtype_id
# 5      13538
# 8        364
# 30       284
# 49       178
# 43       162
# 1        103
# 324       60
# 23        45
# 281        7
# 19         6
# 24         6
# 212        2
# 182        1
# 79         1
# Name: count, dtype: int64
# ship_status_id
# 2     13215
# 1      1398
# 5       117
# 12       22
# 11        5
# Name: count, dtype: int64
# flag_id
# 170.0    2961
# 124.0    2418
# 137.0    2165
# 45.0     1440
# 98.0     1005
#          ...
# 134.0       1
# 78.0        1
# 69.0        1
# 61.0        1
# 34.0        1
# Name: count, Length: 100, dtype: int64
# design_id
# 1314.0    535
# 1339.0    448
# 1365.0    388
# 1543.0    255
# 1331.0    245
#          ...
# 1443.0      1
# 2617.0      1
# 2891.0      1
# 1530.0      1
# 1379.0      1
# Name: count, Length: 220, dtype: int64
# category_id
# 21    3088
# 25    2451
# 23    2051
# 22    1962
# 17    1735
# 26    1556
# 24     839
# 20     615
# 16     283
# 19     143
# 18      34
# Name: count, dtype: int64
# demolition_country_id
# 45.0     2
# 19.0     1
# 101.0    1
# Name: count, dtype: int64
# market_segment_id
# 6    14749
# 3        8
# Name: count, dtype: int64
# exnames
# ZHEJIANG DONGHONG (TBA)                             12
# CHINA SHIPPING JIANGSU                              11
# NEW DAYANG (TBA)                                     5
# ZHEJIANG HEXING (TBA)                                4
# FUJIAN LIXIN (TBA)                                   4
#                                                     ..
# GMI TARITA,JIANGSU NEWYANGZI YZJ2013 1056            1
# GMI STEPHANIE,JIANGSU NEWYANGZI YZJ2013 1065         1
# GMI EDWARD,JIANGSU NEWYANGZI YZJ2013 1066            1
# TRADE QUEST,JIANGSU NEW YANGZIJIANG YZJ2013-1052     1
# YUE LONG LAN HAI                                     1
# Name: count, Length: 12653, dtype: int64
# me_builder
# Mitsui Engineering & Shipbuilding C Ltd - Japan    2596
# Hudong Heavy Machinery Co. Ltd                      926
# Makita Corp - Japan                                 590
# Hitachi Zosen Corp - Japan                          530
# Kawasaki Heavy Industries, Ltd.                     422
#                                                    ...
# Uljanik                                               1
# Fairbanks Morse & Co. - New Orleans, La               1
# AB NOHAB - Sweden                                     1
# Caterpillar Motoren GmbH & Co. KG - Kiel              1
# MAN B&W Diesel Kobe, Japan                            1
# Name: count, Length: 246, dtype: int64
# me_design
# MAN B&W                 10659
# Mitsubishi                644
# Wartsila                  607
# Sulzer                    223
# CHINESE STANDARD          136
#                         ...
# HHM-MAN B&W                 1
# CSE-MAN B&W                 1
# MAN B&W 6S60ME-C10.5        1
# IHI                         1
# Yanmar (x2)                 1
# Name: count, Length: 63, dtype: int64
# me_model
# 6S50MC-C                 1511
# 6 S42MC                   551
# 6S70MC-C                  549
# 6S 60ME-C8                536
# 6 S60MC-C                 504
#                          ...
# 6G70ME-C10.5-GI-HPSCR       1
# 6G80ME-C10.5                1
# 6UEC42LSH-EcoD3-LPSCR       1
# 6190ZLC                     1
# 8PC2-2L-400                 1
# Name: count, Length: 722, dtype: int64
# me_kw_total
# 0        1507
# 9480      564
# 8050      239
# 8055      199
# 9660      195
#          ...
# 10055       1
# 6303        1
# 6002        1
# 9975        1
# 19660       1
# Name: count, Length: 1592, dtype: int64
# me_hp
# 0        14646
# 1468        26
# 1001        10
# 2000         7
# 1500         5
# 799          5
# 12954        3
# 25370        3
# 1300         2
# 22920        2
# 2101         2
# 812          2
# 1800         2
# 408          2
# 2600         2
# 1496         2
# 980          2
# 866          1
# 2400         1
# 470          1
# 2447         1
# 851          1
# 2999         1
# 3001         1
# 1447         1
# 1740         1
# 1922         1
# 999          1
# 979          1
# 4000         1
# 1400         1
# 1320         1
# 1262         1
# 7699         1
# 950          1
# 900          1
# 1550         1
# 600          1
# 2515         1
# 1201         1
# 3481         1
# 1020         1
# 650          1
# 549          1
# 750          1
# 392          1
# 738          1
# 22591        1
# 1761         1
# 13542        1
# 4038         1
# Name: count, dtype: int64
# me_rpm
# 0        14594
# 99          22
# 900         21
# 825         11
# 91           9
# 105          7
# 600          7
# 108          6
# 250          6
# 100          6
# 89           5
# 106          5
# 720          4
# 85           4
# 1200         3
# 92           3
# 95           3
# 1800         3
# 300          3
# 1500         2
# 1400         2
# 260          2
# 330          2
# 750          2
# 1000         2
# 14940        2
# 90           2
# 350          1
# 270          1
# 500          1
# 75           1
# 84           1
# 80           1
# 1650         1
# 295          1
# 110          1
# 127          1
# 403          1
# 288          1
# 775          1
# 88           1
# 210          1
# 114          1
# 400          1
# 390          1
# 525          1
# Name: count, dtype: int64
# ae_number
# 0    14722
# 1       19
# 3        8
# 2        5
# 4        3
# Name: count, dtype: int64
# Series([], Name: count, dtype: int64)
# next_dd_date
# 2025-06-28    16
# 2025-04-16    13
# 2025-07-25    13
# 2025-09-28    12
# 2025-01-28    12
#               ..
# 2020-08-07     1
# 2024-08-05     1
# 2023-08-10     1
# 2026-04-04     1
# 2020-12-01     1
# Name: count, Length: 1672, dtype: int64
# last_ss_date
# 2020-06-30    21
# 2021-02-06    19
# 2022-01-26    18
# 2022-01-29    17
# 2024-03-25    16
#               ..
# 2017-02-04     1
# 2018-04-14     1
# 2023-01-07     1
# 2017-12-14     1
# 2019-05-28     1
# Name: count, Length: 2003, dtype: int64
# next_ss_date
# 2026-01-11    26
# 2025-06-29    25
# 2027-01-17    25
# 2027-03-29    25
# 2026-03-29    24
#               ..
# 2024-01-25     1
# 2023-10-27     1
# 2028-12-12     1
# 2028-12-19     1
# 2023-12-31     1
# Name: count, Length: 2081, dtype: int64
# class_society
# NK    4500
# LR    1577
# CC    1406
# AB    1313
# BV    1218
# NG     981
# RI     694
# KR     496
# VR     124
# NN     104
# PR      94
# NO      75
# IR      59
# KI      38
# RS      24
# CR      13
# IB      11
# TL       9
# UU       4
# HR       4
# CS       3
# KC       2
# YY       2
# Name: count, dtype: int64
# cranes_type
# Crane            7408
# Unknown          1306
# Bulk Conveyor      57
# Derrick            47
# Gantry Crane        8
# Crawler             2
# Grab                1
# Name: count, dtype: int64
# cranes_number
# 0     7252
# 4     6808
# 3      468
# 2      133
# 1       82
# 5       10
# 10       2
# 7        1
# 8        1
# Name: count, dtype: int64
# cranes_swl
# 0.00     7270
# 30.00    4082
# 30.50    1239
# 36.00     686
# 35.00     578
#          ...
# 34.00       1
# 30.26       1
# 65.00       1
# 30.76       1
# 7.50        1
# Name: count, Length: 74, dtype: int64
# cranes_outreach
# 0     14750
# 45        2
# 30        1
# 10        1
# 5         1
# 28        1
# 26        1
# Name: count, dtype: int64
# Series([], Name: count, dtype: int64)
# hold_details
# No. 1 : - cbm;No. 2 : - cbm;No. 3 : - cbm;No. 4 : - cbm;No. 5 : - cbm                                                            580
# No. 1 : - cbm;No. 2 : - cbm;No. 3 : - cbm;No. 4 : - cbm;No. 5 : - cbm;No. 6 : - cbm;No. 7 : - cbm                                395
# No. 1 : - cbm;No. 2 : - cbm;No. 3 : - cbm;No. 4 : - cbm;No. 5 : - cbm;No. 6 : - cbm;No. 7 : - cbm;No. 8 : - cbm;No. 9 : - cbm    296
# No. 1 : 13009.9 cbm;No. 2 : 15333.2 cbm;No. 3 : 14553.1 cbm;No. 4 : 15333.3 cbm;No. 5 : 13404.6 cbm                              274
# No. 1 : - cbm;No. 2 : - cbm                                                                                                      108
#                                                                                                                                 ...
# No. 1 : 13009.9 cbm;No. 2 : 15333.2 cbm;No. 3 : 14553.1 cbm;No. 4 : 14533.3 cbm;No. 5 : 13404.6 cbm                                1
# No. 1 : 13009.8 cbm;No. 2 : 15333.2 cbm;No. 3 : 14553 cbm;No. 4 : 15332.7 cbm;No. 5 : 13404.6 cbm                                  1
# No. 1 : 12060 cbm;No. 2 : 15706.7 cbm;No. 3 : 14777.2 cbm;No. 4 : 14770.4 cbm;No. 5 : 14747.7 cbm                                  1
# No. 1 : 18869.7 cbm;No. 2 : 21007.6 cbm;No. 3 : 17996.1 cbm;No. 4 : 21167.2 cbm;No. 5 : 19847.2 cbm                                1
# No. 1 : 5876 cbm;No. 2 : 5884 cbm;No. 3 : 5884 cbm;No. 4 : 6187 cbm                                                                1
# Name: count, Length: 2579, dtype: int64
# hatches_details
# No. 1 : 18.86 m X 18.26 m;No. 2 : 21.32 m X 18.26 m;No. 3 : 21.32 m X 18.26 m;No. 4 : 21.32 m X 18.26 m;No. 5 : 21.32 m X 18.26 m    517
# No. 1 : 19.68 m X 18.26 m;No. 2 : 22.96 m X 18.26 m;No. 3 : 22.96 m X 18.26 m;No. 4 : 22.96 m X 18.26 m;No. 5 : 22.96 m X 18.26 m    259
# No. 1 : 18.4 m X 18.72 m;No. 2 : 23.2 m X 18.72 m;No. 3 : 23.2 m X 18.72 m;No. 4 : 23.2 m X 18.72 m;No. 5 : 23.2 m X 18.72 m         236
# No. 1 : 13.6 m X 16 m;No. 2 : 19.2 m X 17.6 m;No. 3 : 19.2 m X 17.6 m;No. 4 : 19.2 m X 17.6 m;No. 5 : 19.2 m X 17.6 m                201
# No. 1 : - m X - m;No. 2 : - m X - m;No. 3 : - m X - m;No. 4 : - m X - m;No. 5 : - m X - m                                            173
#                                                                                                                                     ...
# No. 1 : 19.2 m X 20.8 m;No. 2 : 21.6 m X 22.4 m;No. 3 : 21.62 m X 22.4 m;No. 4 : 21.6 m X 22.4 m;No. 5 : 21.6 m X 22.4 m               1
# No. 1 : 19.8 m X 25.8 m;No. 2 : 19.92 m X 25.8 m;No. 3 : 19.92 m X 25.8 m;No. 4 : 19.92 m X 25.8 m;No. 5 : 19.92 m X 25.8 m            1
# No. 1 : 16.4 m X 16.1 m;No. 2 : 21.32 m X 17.7 m;No. 3 : 21.32 m X 17.7 m;No. 4 : 21.32 m X 17.7 m;No. 5 : 21.32 m X 17.7 m            1
# No. 1 : 19.2 m X 20.8 m;No. 1 : 21.6 m X 22.4 m;No. 3 : 21.6 m X 22.4 m;No. 4 : 21.6 m X 22.4 m;No. 5 : 21.6 m X 22.4 m                1
# No. 1 : 18.9 m X 11 m;No. 2 : 18.9 m X 11 m;No. 3 : 18.9 m X 11 m                                                                      1
# Name: count, Length: 1720, dtype: int64
# private_comments
# 0    14757
# Name: count, dtype: int64
# Series([], Name: count, dtype: int64)
# conversion_date
# 2012-01-01    1
# Name: count, dtype: int64
# Series([], Name: count, dtype: int64)

# %% [markdown]
# #### From the above inspection, we can see unstructured axs_notes_dry and tts.
# if they're not meaningful, drop otherwise parse the meaningful information
# #### We can also see that demolition_date, active, cancelled_date, vlsfo_tank,'private_comments','conversion_date'
# have only one unique value so they can be dropped for the lack of variation
# <br>
# #### note: keel_laying_date and launching_date have 0000-00-00 as an entry
# <br>
#
# #### These columns can be dropped because they are empty:
# 'technical_manager','parent_shipowner','doc_holder','crew_manager','ism_manager', <br>
# 'technical_manager_id','technical_manager_flag','technical_manager_flag_id', 'parent_shipowner_id',<br>
# 'parent_shipowner_flag','parent_shipowner_flag_id','doc_holder_id','doc_holder_flag','doc_holder_flag_id',<br>
# 'crew_manager_id','crew_manager_flag','crew_manager_flag_id','ism_manager_id','ism_manager_flag',<br>
# 'ism_manager_flag_id', 'last_dd_date', 'cranes_position', 'private_tags', 'private_notes',<br>
#
# ####  These columns can be dropped because they are sparse:
# 'pool', 'demolition_country', 'second_shipyard_flag', <br>
# 'second_shipyard_flag_id', 'pool_id', 'pool_flag','pool_flag_id', <br>
# 'demolition_country_id' (this seems like a duplicate feature), <br>
# 'market_segment_id',
#
# #### hold_details has unstructured data in the form:
# No. 1 : - cbm;No. 2 : 15333.2 cbm;No. 3 : 14553.1 cbm;No. 4 : 15333.3 cbm;No. 5 : 13404.6 cbm
# <br>
# if it's a meaningful feature, extract the data as a list of numbers or nan for -, otherwise drop
# <br>
# #### hatches_details has unstructured data in the form:
# No. 1 : 18.9 m X 11 m;No. 2 : 18.9 m X 11 m;No. 3 : 18.9 m X 11 m                                                                      1
# <br>
# if it's a meaningful feature, extract the data as a 2D list of dimensions ex: [[18.9x11],[18.9x11],[18.9x11]]

# %% [markdown]
# ## Handling of Sparse Features

# %%
# Function to show missing proportion per column
def missing_report(df):
    return (df.isnull().sum() / len(df)).sort_values(ascending=False)

# %%
print("---Missingness in vessel_positions---")
display(missing_report(positions))
# Out:
# ---Missingness in vessel_positions---
# port_entry_time                    0.769708
# port_out_time                      0.769708
# waiting_zone_out_time              0.682236
# waiting_zone_entry_time            0.682236
# waiting_zone_name                  0.682236
# waiting_zone_id                    0.682236
# port_id                            0.658044
# country_id                         0.658044
# port_name                          0.658044
# country_name                       0.658044
# operation_location_out_time        0.657681
# operation_location_entry_time      0.657681
# operation_location_type            0.657681
# operation_location_id              0.657681
# operation_location_name            0.657681
# vessel_commodity_onboard           0.453312
# vessel_commodity_group_onboard     0.453312
# voyage_intake_mt                   0.403783
# vessel_speed_ratio                 0.122147
# real_destination_country_id        0.028869
# real_destination_port_id           0.028869
# real_destination_country_name      0.028869
# real_destination_zone_id           0.028869
# real_destination_zone_name         0.028869
# real_destination_port_name         0.028869
# ais_destination_normalized         0.025058
# origin_port_id                     0.023006
# origin_port_name                   0.023006
# origin_country_id                  0.023006
# origin_country_name                0.023006
# origin_zone_id                     0.023006
# origin_zone_name                   0.023006
# zone_out_time                      0.007022
# zone_entry_time                    0.006463
# zone_name                          0.006463
# zone_id                            0.006463
# ais_destination_raw                0.001563
# ais_heading                        0.000838
# last_seen                          0.000754
# vessel_operational_status          0.000754
# vessel_operational_status_group    0.000754
# updated_at                         0.000754
# vessel_draft_status                0.000754
# ais_long                           0.000014
# ais_lat                            0.000014
# ais_eta                            0.000000
# imo                                0.000000
# ais_draft                          0.000000
# ais_speed                          0.000000
# in_blackout                        0.000000
# status_date_time                   0.000000
# vessel_dwt                         0.000000
# during_cabotage_voyage             0.000000
# index                              0.000000
# dtype: float64

# %%
#i'll drop columns with >65% missingness for sparsity
missing_thresh = 0.65
high_missing_cols = missing_report(positions)[lambda x: x > missing_thresh].index.tolist()
positions.drop(columns=high_missing_cols, inplace=True)

# %%
missing_report(positions)
# Out:
# vessel_commodity_group_onboard     0.453312
# vessel_commodity_onboard           0.453312
# voyage_intake_mt                   0.403783
# vessel_speed_ratio                 0.122147
# real_destination_country_id        0.028869
# real_destination_zone_name         0.028869
# real_destination_zone_id           0.028869
# real_destination_country_name      0.028869
# real_destination_port_id           0.028869
# real_destination_port_name         0.028869
# ais_destination_normalized         0.025058
# origin_country_name                0.023006
# origin_country_id                  0.023006
# origin_port_name                   0.023006
# origin_port_id                     0.023006
# origin_zone_id                     0.023006
# origin_zone_name                   0.023006
# zone_out_time                      0.007022
# zone_entry_time                    0.006463
# zone_id                            0.006463
# zone_name                          0.006463
# ais_destination_raw                0.001563
# ais_heading                        0.000838
# vessel_operational_status          0.000754
# last_seen                          0.000754
# vessel_operational_status_group    0.000754
# updated_at                         0.000754
# vessel_draft_status                0.000754
# ais_long                           0.000014
# ais_lat                            0.000014
# imo                                0.000000
# ais_eta                            0.000000
# ais_draft                          0.000000
# ais_speed                          0.000000
# in_blackout                        0.000000
# status_date_time                   0.000000
# vessel_dwt                         0.000000
# during_cabotage_voyage             0.000000
# index                              0.000000
# dtype: float64

# %% [markdown]
# #### Since this is not an ML modeling task, blindly imputing features is unnecessary

# %%
print("---Missingness in vessel_characteristics---")
display(missing_report(characteristics))
# Out:
# ---Missingness in vessel_characteristics---
# private_notes           1.0
# doc_holder_flag         1.0
# parent_shipowner        1.0
# technical_manager       1.0
# parent_shipowner_id     1.0
#                        ...
# full_laden_ae_lsmgo     0.0
# eco_ballast_ae_lsmgo    0.0
# eco_laden_ae_lsmgo      0.0
# port_load_ae_lsmgo      0.0
# full_laden_vlsfo        0.0
# Length: 212, dtype: float64

# %%
# Filter and display only columns with > 65% missingness
high_missing = missing_report(characteristics)
display(high_missing[high_missing > 0.65])
# Out:
# private_notes                1.000000
# doc_holder_flag              1.000000
# parent_shipowner             1.000000
# technical_manager            1.000000
# parent_shipowner_id          1.000000
# parent_shipowner_flag        1.000000
# parent_shipowner_flag_id     1.000000
# doc_holder_id                1.000000
# doc_holder_flag_id           1.000000
# crew_manager                 1.000000
# crew_manager_id              1.000000
# crew_manager_flag            1.000000
# crew_manager_flag_id         1.000000
# ism_manager_id               1.000000
# ism_manager_flag             1.000000
# ism_manager_flag_id          1.000000
# doc_holder                   1.000000
# last_dd_date                 1.000000
# ism_manager                  1.000000
# private_tags                 1.000000
# technical_manager_flag_id    1.000000
# technical_manager_id         1.000000
# cranes_position              1.000000
# technical_manager_flag       1.000000
# pool_flag                    0.999932
# conversion_date              0.999932
# pool_flag_id                 0.999932
# second_shipyard              0.999932
# pool_id                      0.999932
# pool                         0.999932
# second_shipyard_id           0.999932
# second_shipyard_flag         0.999932
# second_shipyard_flag_id      0.999932
# demolition_country           0.999729
# demolition_country_id        0.999729
# stern_thruster               0.998848
# bow_thruster                 0.987260
# lakes_fitted                 0.975266
# dual_fuel                    0.969642
# ice_class                    0.947686
# open_hatches                 0.915091
# logs_fitted                  0.894694
# scrubbers                    0.885681
# axs_notes_dry                0.818459
# ahl_fitted                   0.732330
# bwts                         0.706377
# next_dd_date                 0.704005
# dtype: float64

# %%
high_missing_cols = high_missing[high_missing > 0.65].index.tolist()
characteristics.drop(columns = high_missing_cols, inplace = True)

# %%
# also drop the unstructured features like: axs_notes_dry , tts, hatches_details, hold_details
characteristics.drop(columns = ['hatches_details', 'hold_details', 'tts'], inplace = True)

# %% [markdown]
# ### Fix Negative and Outlier Values

# %%
# Only keep rows with valid AIS coordinates
positions = positions[
    (positions['ais_lat'].between(-90, 90)) &
    (positions['ais_long'].between(-180, 180))
]

# %% [markdown]
# I intentionally **did not remove outliers** at this stage.
# Instead, I preserved all records, including extreme values in features such as:
# - `ais_speed`
# - `ais_draft`
#
# I will visually inspect these variables during the **Exploratory Data Analysis** phase using boxplots and histograms.
# This helps us better understand the spread and detect potential operational anomalies.

# %% [markdown]
# ## Handling Remaining NaNs

# %%
positions[positions['ais_draft'].isnull() == True]
# Out:
# Empty DataFrame
# Columns: [index, imo, vessel_dwt, status_date_time, in_blackout, ais_speed, ais_draft, vessel_speed_ratio, ais_lat, ais_long, vessel_draft_status, zone_id, zone_name, zone_entry_time, zone_out_time, updated_at, ais_heading, ais_eta, ais_destination_raw, ais_destination_normalized, origin_port_id, origin_port_name, origin_country_id, origin_country_name, origin_zone_id, origin_zone_name, real_destination_port_id, real_destination_port_name, real_destination_country_id, real_destination_country_name, real_destination_zone_id, real_destination_zone_name, vessel_operational_status, vessel_commodity_onboard, vessel_commodity_group_onboard, voyage_intake_mt, last_seen, during_cabotage_voyage, vessel_operational_status_group]
# Index: []
#
# [0 rows x 39 columns]

# %%
positions[positions['ais_speed'].isnull() == True]
# Out:
# Empty DataFrame
# Columns: [index, imo, vessel_dwt, status_date_time, in_blackout, ais_speed, ais_draft, vessel_speed_ratio, ais_lat, ais_long, vessel_draft_status, zone_id, zone_name, zone_entry_time, zone_out_time, updated_at, ais_heading, ais_eta, ais_destination_raw, ais_destination_normalized, origin_port_id, origin_port_name, origin_country_id, origin_country_name, origin_zone_id, origin_zone_name, real_destination_port_id, real_destination_port_name, real_destination_country_id, real_destination_country_name, real_destination_zone_id, real_destination_zone_name, vessel_operational_status, vessel_commodity_onboard, vessel_commodity_group_onboard, voyage_intake_mt, last_seen, during_cabotage_voyage, vessel_operational_status_group]
# Index: []
#
# [0 rows x 39 columns]

# %%
print(positions['vessel_operational_status'].isnull().sum() / len(positions))
# Out:
# 0.0007538530265802993

# %% [markdown]
# #### Since < 0.01% of vessel_operational_status are empty, we can safely drop them

# %%
positions.dropna(subset=['vessel_operational_status'], inplace=True)

# %% [markdown]
# ### Step 1 Summary: Data Loading and Cleaning
#
# - Loaded both datasets
# - Inspected features and spotted erroneous data points
# - Dropped timestamp columns with inconsistent formats
# - Dropped low-variance and empty columns from `vessel_characteristics.csv` and `vessel_positions.csv`
# - Removed missing vessel_operational_status data

# %% [markdown]
# # 2. Exploratory Analysis – Operational Status, Speed, and Draft

# %% [markdown]
# We explore how vessel movement behavior (`ais_speed` and `ais_draft`) varies by operational status using descriptive statistics, box plots, and scatter plots.

# %% [markdown]
# We first inspect the distribution of vessel operational statuses to identify the most common ones for deeper analysis.

# %%
positions['vessel_operational_status'].value_counts(dropna=False)
# Out:
# vessel_operational_status
# at_sea_laden               25791
# at_sea_ballast             21266
# at_port_discharging         5830
# at_port_load                5341
# waiting_load                4503
# waiting_discharge           4222
# waiting_at_anchorage        2824
# in_shipyard                 1393
# waiting_shipyard             154
# bunkering_while_laden         95
# bunkering_while_ballast       73
# at_port_load_sts              33
# at_port_discharge_sts         18
# passing_canal_laden           13
# passing_canal_ballast         13
# sts                            9
# Name: count, dtype: int64

# %% [markdown]
# ### Distribution of vessel_operational_status

# %%
plt.figure(figsize=(10, 6))
positions['vessel_operational_status'].value_counts().plot(kind='barh')
plt.title("Vessel Operational Status Distribution")
plt.xlabel("Number of Records")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### The 6 most significant categories are `at_sea_laden` , `at_sea_ballast`, `at_port_discharging`, `at_port_load`, `waiting_load`, `waiting_discharge`

# %%
positions[['ais_speed', 'ais_draft']].describe()
# Out:
#           ais_speed     ais_draft
# count  71578.000000  71578.000000
# mean       6.061723      9.761184
# std        6.415371      3.408525
# min        0.000000      0.000000
# 25%        0.000000      7.100000
# 50%        8.000000      9.200000
# 75%       11.200000     12.000000
# max      102.300000     25.500000

# %% [markdown]
# #### The table above shows descriptive statistics for `ais_speed` and `ais_draft`. We observe:
# - Average AIS speed is ~6 knots, with a max over 100 (likely an outlier).
# - Average draft is ~9.76m, peaking at 25.5m.
# - Zero values in speed and draft likely represent stationary or unloaded vessels.

# %%
top_statuses = [
    'at_sea_laden',
    'at_sea_ballast',
    'at_port_discharging',
    'at_port_load',
    'waiting_load',
    'waiting_discharge'
]

subset = positions[positions['vessel_operational_status'].isin(top_statuses)]

# %% [markdown]
# ### vessel_operational_status vs ais_speed

# %%
plt.figure(figsize=(12,6))
sns.boxplot(data=subset, x='vessel_operational_status', y='ais_speed')
plt.title('AIS Speed by Vessel Operational Status')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# `at_sea_ballast` and `at_sea_laden` vessels show the highest speeds. Vessels at port or waiting have speeds close to 0, which confirms their idle state.

# %% [markdown]
# ### vessel_operational_status vs ais_draft

# %%
plt.figure(figsize=(12,6))
sns.boxplot(data=subset, x='vessel_operational_status', y='ais_draft')
plt.title('AIS Draft by Vessel Operational Status')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# `at_sea_laden` and `at_port_discharging` and `waiting_discharge` vessels show **consistently higher AIS draft values**, confirming they are heavily loaded.
#
# `at_sea_ballast` vessels exhibit **notably lower draft values**, which aligns with their empty (ballast) condition.
#
# `at_port_load` and `waiting_load` vessels also tend to have **lower drafts**, indicating that they have not yet taken on full cargo.

# %% [markdown]
# ### Scatterplot: Speed vs Draft Colored by Status

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(
    data=subset,
    x='ais_speed',
    y='ais_draft',
    hue='vessel_operational_status',
    alpha=0.6
)
plt.title("AIS Speed vs Draft by Vessel Operational Status")
plt.tight_layout()
plt.show()

# %% [markdown]
# This scatterplot reveals several distinct behavioral clusters:
#
# - **Waiting and Port-based vessels** (e.g., `waiting_load`, `at_port_load`, `waiting_discharge`, `at_port_discharging`) are tightly clustered around **0 AIS speed**, with a wide range of drafts. This confirms their mostly stationary behavior while loading or unloading.
#
# - **At-sea vessels**:
#   - `at_sea_laden` (green) vessels show **higher drafts** and are more spread out across a range of low to moderate speeds (5–20 knots), confirming they are loaded and underway.
#   - `at_sea_ballast` (red) vessels generally have **lower drafts** and slightly higher speeds, consistent with empty vessels in transit.
#
# - A few extreme outliers exist with speeds above 50 knots — these may be **erroneous AIS reports or sensor glitches**.
#
# Overall, this plot demonstrates the relationship between operational status and a vessel’s physical condition and movement, revealing clear behavior patterns.

# %% [markdown]
# ### Step 2 Summary: Exploratory Analysis Insights
#
# This exploratory analysis investigated how vessel movement behavior (speed and draft) varies with operational status.
#
# #### Key Insights:
#
# - **Operational Behavior**:
#   - `at_sea_laden` vessels operate at moderate speeds with **high drafts**, indicating fully loaded conditions.
#   - `at_sea_ballast` vessels exhibit **higher speeds and lower drafts**, confirming empty return voyages.
#   - Port-related statuses such as `at_port_load` and `at_port_discharging` show **very low speeds**, with draft levels indicating cargo intake or offloading.
#   - `waiting_load` and `waiting_discharge` statuses cluster around **0 speed**, with moderate to high drafts — suggesting vessels are loaded and awaiting terminal access.
#
# - **AIS Speed and Draft Distribution**:
#   - The **median AIS speed** is ~8 knots, but many records are at 0, especially for idle vessels.
#   - AIS draft ranges widely, with a **median around 9.2 meters** and outliers up to 25m.
#   - Some extreme AIS speeds (>50 knots) likely represent **sensor or reporting errors**, which we retain for completeness but highlight as potential outliers.
#
# - **Relationship Between Status, Speed, and Draft**:
#   - Clear behavioral clusters emerge from the scatterplot:
#     - **Low speed + high draft** → port or waiting, fully loaded
#     - **High speed + low draft** → in transit, empty
#     - **Medium speed + high draft** → laden vessels at sea
#
# This triad (status, speed, draft) offers a strong behavioral fingerprint that will be useful when classifying vessel types and analyzing cargo patterns in later stages.

# %% [markdown]
# # 3.  Add New Dimension

# %%
positions['vessel_dwt']
# Out:
# 0         11717
# 1         39815
# 2         11722
# 3         13465
# 4         39415
#           ...
# 71630    210870
# 71631    181283
# 71632    181283
# 71633    182498
# 71634    182316
# Name: vessel_dwt, Length: 71578, dtype: int64

# %%
def classify_vessel(dwt):
    if dwt >= 100000:
        return 'Capsesize'
    elif dwt >= 60000:
        return 'Panamax'
    elif dwt >= 40000:
        return 'Supramax'
    elif dwt >= 10000:
        return 'Handymax'
    else:
        return None

# %%
# Apply to vessel_dwt
positions['vessel_class'] = positions['vessel_dwt'].apply(classify_vessel)

# %% [markdown]
# ### Number of rows per vessel_class

# %%
class_counts = positions.groupby('vessel_class').size().sort_values(ascending=False)
class_counts
# Out:
# vessel_class
# Handymax     23798
# Panamax      23406
# Supramax     14247
# Capsesize    10123
# dtype: int64

# %%
plt.figure(figsize= (10,6))
class_counts.plot(kind='bar')
plt.title("Number of Records per Vessel Class")
plt.xlabel("Vessel Class")
plt.ylabel("Count")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Unique vessels_class count by unique IMO

# %%
class_counts_imo = positions.groupby('vessel_class')['imo'].nunique().sort_values(ascending=False)
class_counts_imo
# Out:
# vessel_class
# Handymax     4763
# Panamax      4684
# Supramax     2850
# Capsesize    2025
# Name: imo, dtype: int64

# %%
plt.figure(figsize= (10,6))
class_counts_imo.plot(kind='bar')
plt.title("Vessel Class By Unique IMO Distribution")
plt.xlabel("Vessel Class")
plt.ylabel("Count")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Summary stats per vessel_class

# %%
positions.groupby('vessel_class')[['ais_speed', 'ais_draft']].describe()
# Out:
#              ais_speed                                                     \
#                  count      mean       std  min  25%   50%     75%    max
# vessel_class
# Capsesize      10123.0  7.758086  5.273633  0.0  0.2  10.0  11.600  102.2
# Handymax       23798.0  5.372409  7.066460  0.0  0.0   0.3  11.000  102.3
# Panamax        23406.0  6.424686  5.772553  0.0  0.0   9.1  11.375  102.3
# Supramax       14247.0  5.410781  6.736538  0.0  0.0   0.5  11.000  102.3
#
#              ais_draft
#                  count       mean       std  min  25%   50%   75%   max
# vessel_class
# Capsesize      10123.0  13.570197  4.348670  0.3  9.4  12.4  18.0  23.3
# Handymax       23798.0   7.684759  1.961109  0.0  6.1   7.6   9.5  25.5
# Panamax        23406.0  10.452555  2.876987  0.0  7.5  10.9  13.1  24.1
# Supramax       14247.0   9.387352  2.544267  0.0  6.8   9.8  11.8  25.3

# %% [markdown]
# ### Summary of AIS Speed and Draft by Vessel Class
#
# This table provides a descriptive statistical overview of how vessel movement characteristics vary by size class.
#
# #### Key Observations:
#
# - **Capesize vessels**:
#   - Exhibit the **highest average draft** (13.57m) and **highest average speed** (7.76 knots), indicating they are typically large, heavily loaded, and in active transit.
#   - Their wider range of drafts (up to ~23.0m) suggests significant cargo capacity variations.
#
# - **Panamax vessels**:
#   - Show a **moderate draft** (10.45m) and **higher-than-average speed** (6.42 knots), consistent with their usage for long-range shipping routes in canals and constrained channels.
#
# - **Supramax and Handymax vessels**:
#   - Both classes exhibit **lower average speeds** (5.37–5.41 knots) and **shallower drafts** (7.68-9.39m), typically involved in more regional or port-focused operations.
#   - Handymax vessels also have the **widest variance in draft**, peaking at 25.5m — likely due to specialized loading scenarios or port conditions.
#
# These patterns confirm that vessel size influences not only physical characteristics but also operational behavior on the water.

# %% [markdown]
# # 4. Cargo Analysis

# %%
positions[['vessel_class','vessel_commodity_group_onboard']].value_counts()
# Out:
# vessel_class  vessel_commodity_group_onboard
# Panamax       Coal                              4791
# Capsesize     Iron Ore                          3521
# Panamax       Grain                             3439
# Handymax      Bulk                              2553
# Supramax      Bulk                              2323
# Panamax       Bulk                              2147
# Handymax      Steels                            1933
# Supramax      Coal                              1904
# Handymax      Grain                             1794
#               Breakbulk                         1548
#               Fertilizers                       1312
# Capsesize     Coal                              1046
# Supramax      Steels                            1037
# Handymax      Agriprods                          940
# Panamax       Agriprods                          887
# Handymax      Coal                               873
# Supramax      Grain                              873
#               Breakbulk                          872
# Panamax       Fertilizers                        841
# Capsesize     Bulk                               644
# Panamax       Steels                             643
#               Iron Ore                           622
# Supramax      Fertilizers                        547
# Panamax       Breakbulk                          501
# Supramax      Agriprods                          444
#               Iron Ore                           263
# Handymax      Iron Ore                           210
#               Project Cargoes                    197
#               Pellets Group                      128
# Supramax      Iron Products                       59
# Handymax      Iron Products                       56
# Panamax       Iron Products                       37
# Supramax      Project Cargoes                     36
#               Pellets Group                       22
# Panamax       Pellets Group                       18
#               Project Cargoes                     14
# Capsesize     Coal/Iron Ore                       14
# Handymax      Bulk/Steels                         14
# Supramax      Iron Products/Steels                 9
# Handymax      Breakbulk/Steels                     7
# Capsesize     Agriprods                            5
# Supramax      Breakbulk/Bulk                       5
# Capsesize     Fertilizers                          5
# Panamax       Coal/Iron Ore                        5
# Capsesize     Breakbulk                            5
# Handymax      Bulk/Iron Ore                        5
#               Bulk/Iron Products                   4
# Supramax      Coal/Steels                          2
#               Bulk/Iron Ore                        1
# Handymax      Breakbulk/Bulk                       1
# Name: count, dtype: int64

# %% [markdown]
# ## Basic Crosstab

# %%
pd.crosstab(positions['vessel_class'], positions['vessel_commodity_group_onboard'])
# Out:
# vessel_commodity_group_onboard  Agriprods  Breakbulk  Breakbulk/Bulk  \
# vessel_class
# Capsesize                               5          5               0
# Handymax                              940       1548               1
# Panamax                               887        501               0
# Supramax                              444        872               5
#
# vessel_commodity_group_onboard  Breakbulk/Steels  Bulk  Bulk/Iron Ore  \
# vessel_class
# Capsesize                                      0   644              0
# Handymax                                       7  2553              5
# Panamax                                        0  2147              0
# Supramax                                       0  2323              1
#
# vessel_commodity_group_onboard  Bulk/Iron Products  Bulk/Steels  Coal  \
# vessel_class
# Capsesize                                        0            0  1046
# Handymax                                         4           14   873
# Panamax                                          0            0  4791
# Supramax                                         0            0  1904
#
# vessel_commodity_group_onboard  Coal/Iron Ore  Coal/Steels  Fertilizers  \
# vessel_class
# Capsesize                                  14            0            5
# Handymax                                    0            0         1312
# Panamax                                     5            0          841
# Supramax                                    0            2          547
#
# vessel_commodity_group_onboard  Grain  Iron Ore  Iron Products  \
# vessel_class
# Capsesize                           0      3521              0
# Handymax                         1794       210             56
# Panamax                          3439       622             37
# Supramax                          873       263             59
#
# vessel_commodity_group_onboard  Iron Products/Steels  Pellets Group  \
# vessel_class
# Capsesize                                          0              0
# Handymax                                           0            128
# Panamax                                            0             18
# Supramax                                           9             22
#
# vessel_commodity_group_onboard  Project Cargoes  Steels
# vessel_class
# Capsesize                                     0       0
# Handymax                                    197    1933
# Panamax                                      14     643
# Supramax                                     36    1037

# %% [markdown]
# ## Check how many records exist for each unique combination of `vessel_class` and `vessel_commodity_group_onboard`

# %%
cargo_counts = positions.groupby(['vessel_class', 'vessel_commodity_group_onboard'])['imo'].nunique().unstack().fillna(0)
cargo_counts
# Out:
# vessel_commodity_group_onboard  Agriprods  Breakbulk  Breakbulk/Bulk  \
# vessel_class
# Capsesize                             1.0        1.0             0.0
# Handymax                            216.0      374.0             1.0
# Panamax                             197.0      109.0             0.0
# Supramax                             97.0      193.0             1.0
#
# vessel_commodity_group_onboard  Breakbulk/Steels   Bulk  Bulk/Iron Ore  \
# vessel_class
# Capsesize                                    0.0  142.0            0.0
# Handymax                                     2.0  607.0            1.0
# Panamax                                      0.0  493.0            0.0
# Supramax                                     0.0  543.0            1.0
#
# vessel_commodity_group_onboard  Bulk/Iron Products  Bulk/Steels    Coal  \
# vessel_class
# Capsesize                                      0.0          0.0   230.0
# Handymax                                       1.0          4.0   239.0
# Panamax                                        0.0          0.0  1128.0
# Supramax                                       0.0          0.0   483.0
#
# vessel_commodity_group_onboard  Coal/Iron Ore  Coal/Steels  Fertilizers  \
# vessel_class
# Capsesize                                 3.0          0.0          1.0
# Handymax                                  0.0          0.0        307.0
# Panamax                                   1.0          0.0        186.0
# Supramax                                  0.0          1.0        124.0
#
# vessel_commodity_group_onboard  Grain  Iron Ore  Iron Products  \
# vessel_class
# Capsesize                         0.0     797.0            0.0
# Handymax                        414.0      60.0           14.0
# Panamax                         754.0     157.0            8.0
# Supramax                        198.0      63.0           16.0
#
# vessel_commodity_group_onboard  Iron Products/Steels  Pellets Group  \
# vessel_class
# Capsesize                                        0.0            0.0
# Handymax                                         0.0           28.0
# Panamax                                          0.0            5.0
# Supramax                                         2.0            5.0
#
# vessel_commodity_group_onboard  Project Cargoes  Steels
# vessel_class
# Capsesize                                   0.0     0.0
# Handymax                                   46.0   451.0
# Panamax                                     3.0   139.0
# Supramax                                    9.0   227.0

# %% [markdown]
# ## Stacked Bar Chart of Commodities per Vessel Class

# %%
cargo_counts.plot(kind='bar', stacked=True, figsize=(12,6), colormap='tab20')
plt.title("Commodity Group Distribution per Vessel Class")
plt.ylabel("Number of Unique Vessels")
plt.xlabel("Vessel Class")
plt.legend(title="Commodity Group", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Step 4: Cargo Analysis by Vessel Class
#
# We examined how different vessel classes relate to the types of commodities carried, using the `vessel_commodity_group_onboard` attribute.
#
# #### Key Observations from the Chart:
#
# - **Capesize vessels** carry a **narrow range of commodities**, with a heavy concentration in **Iron Ore**. This aligns with their role in transporting massive, dense bulk cargo over long distances.
#
# - **Panamax vessels** exhibit a **more diverse commodity profile**, but still show strong representation in traditional bulk commodities like **Coal**, **Fertilizers**, **Grain** and **Iron Ore**. Their size allows them to pass through size-constrained routes like the Panama Canal while handling significant cargo.
#
# - **Handymax and Supramax vessels** have the **widest variety of commodity groups**, including:
#   - **Agricultural products (AgriProds)**
#   - **Breakbulk and project cargo**
#   - **Bulk/Steels, Fertilizers, and Grain**
#
#   This diversity reflects their flexibility and common use in regional or multi-port trades.
#
# #### Interpretation:
#
# - There is a **clear link between vessel class and commodity specialization**:
#   - Larger vessels are used for fewer, denser commodities
#   - Smaller vessels serve broader, often mixed logistics needs
#
# - **Operational strategy and trade routes** likely influence these patterns, where vessel class determines not just capacity, but the range of viable cargoes and ports served.

# %% [markdown]
# # 5. Geographical Analysis

# %%
positions['zone_name'].value_counts()
# Out:
# zone_name
# Far East                             17204
# South East Asia                      12361
# East Coast South America              3775
# Indian Ocean                          2765
# Arabian Gulf                          2456
# South Atlantic                        2354
# East Mediterranean                    2180
# East Coast India                      1888
# South Africa                          1817
# North West Africa                     1741
# Black Sea                             1709
# West Mediterranean                    1562
# East Africa                           1456
# East Aussie                           1454
# NoPac                                 1424
# Antwerp Rotterdam Amsterdam Ghent     1163
# Red Sea                               1069
# South West Africa                     1006
# West Aussie                            959
# West Coast India                       902
# USG                                    882
# West Coast Central America             857
# West Coast South America               847
# Baltic                                 795
# Mid-North Atlantic                     752
# Central Atlantic                       610
# East Coast U.S                         547
# North Coast South America              531
# Spain Atlantic                         455
# Carribbean                             441
# Great Lakes                            426
# North Continent                        406
# East Coast Central America             393
# South Indian Ocean                     357
# New Zealand                            332
# Saint Lawrence                         332
# Mid Pacific                            226
# East Coast Canada                      221
# United Kingdom Ireland                 215
# French Atlantic                        178
# North East Passage                      49
# North West Passage                      38
# South Pacific                           34
# Name: count, dtype: int64

# %% [markdown]
# ### Get the unique vessels located in Southeast Asian countries

# %%
SEA_vessels = positions[positions['zone_name'] == 'South East Asia']
unique_imos = SEA_vessels['imo'].unique()
print(f"Total unique vessels in South East Asia: {len(unique_imos)}")
# Out:
# Total unique vessels in South East Asia: 3094

# %% [markdown]
# ## Plotting the Polygon

# %% [markdown]
# ### Polygon and Mapping

# %%
# Define polygon boundary (approx.)
se_asia_poly = Polygon([
    (90, -11),    # SW of Sumatra
    (115, -11),   # South of Java
    (135, -5),    # East of Papua
    (140, 25),    # North of Philippines
    (100, 25),    # Vietnam/Gulf of Thailand
    (90, -11)     # Close polygon
])

# Convert each row into a Point
positions['point'] = positions.apply(lambda row: Point(row['ais_long'], row['ais_lat']), axis=1)

'''
Since this is a time-series data, the same vessel can appear in the same location at multiple timestamps
For clarity, I will plot one point per vessel by filtering on its most recently tracked position
'''

# Latest position for each vessel
positions_latest = positions.sort_values('status_date_time').groupby('imo').tail(1)

# Filter points inside polygon
in_polygon = positions_latest[positions_latest['point'].apply(se_asia_poly.contains)]

# %%
# plot map
plt.figure(figsize=(10,6))
plt.scatter(positions_latest['ais_long'], positions_latest['ais_lat'], s=3, alpha=0.1, color='gray', label='All Vessels')
plt.scatter(in_polygon['ais_long'], in_polygon['ais_lat'], s=5, color='dodgerblue', label='In Southeast Asia')
x, y = se_asia_poly.exterior.xy
plt.plot(x, y, color='red', linewidth=2, label='Defined Polygon')
plt.title("Vessels Inside Southeast Asia Polygon")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Unique Vessels in the Polygon

# %%
vessels_in_polygon = in_polygon['imo'].unique()
print(f"Total unique vessels inside the polygon: {len(vessels_in_polygon)}")
# Out:
# Total unique vessels inside the polygon: 2759

# %%
vessels_df = pd.DataFrame(vessels_in_polygon, columns=['imo'])
vessels_df.head()
# Out:
#            imo
# 66856  9286932
# 66863  9287182
# 66870  9288435
# 66875  9288514
# 66853  9286906

# %% [markdown]
# #### The dataframe above has the IDs (IMOs) of the unique vessels that fall into the Southeast Asian polygon
